# %% [markdown]
# Here we will create a basic n-step policy

# %%
def getImmediateReward(achieved_goals, goal_success_counts, total_timesteps):
    if achieved_goals is None:
        return 0

    total_reward = 0
    for goal_edge, success in achieved_goals:
        if success:
            start, end = goal_edge
            num_edges = abs(end - start)
            instant_rate = pSwap ** (num_edges - 1)

            #edr = max(0.0001, goal_success_counts[goal_edge] / max(1, total_timesteps))
            edr = goal_success_counts[goal_edge] / max(1, total_timesteps) + 0.001

            if instant_rate > 0 and edr > 0:
                total_reward += instant_rate / edr
    return total_reward

# %%
from collections import defaultdict, deque
from itertools import product, combinations
import random
import numpy as np
import matplotlib.pyplot as plt


def getPossibleStates(edges, max_age):
    sorted_edges = sorted(tuple(sorted(e)) for e in edges)
    possible_ages = [-1] + list(range(1, max_age + 1))
    return [tuple(zip(sorted_edges, age_combo)) for age_combo in product(possible_ages, repeat=len(sorted_edges))]

def getAgedStates(state, maxAge):
    new_state = []
    for edge, age in state:
        if age == -1:
            new_state.append((edge, -1))
        else:
            new_age = age + 1
            new_state.append((edge, new_age if new_age <= maxAge else -1))
    return tuple(sorted(new_state))

def generateAllOutcomes(state, pGen):
    empty_edges = [edge for edge, age in state if age == -1]
    outcomes = []
    for pattern in product([0, 1], repeat=len(empty_edges)):
        outcome_map = {edge: 1 if outcome else -1 for edge, outcome in zip(empty_edges, pattern)}
        new_state = [(edge, outcome_map.get(edge, age)) for edge, age in state]
        outcomes.append((tuple(sorted(new_state)), 1.0))
    return outcomes

def generateAllSwappingOutcomes(state, goalEdges, pSwap):
    def find_path(current, target, visited):
        if current == target:
            return [current]
        visited.add(current)
        for next_node in graph.get(current, []):
            if next_node not in visited:
                path = find_path(next_node, target, visited)
                if path:
                    return [current] + path
        return None

    entangled_edges = [(edge, age) for edge, age in state if age > 0]
    graph = defaultdict(list)
    for (edge, _) in entangled_edges:
        graph[edge[0]].append(edge[1])
        graph[edge[1]].append(edge[0])

    swap_attempts = []
    for goal_edge in goalEdges:
        path = find_path(goal_edge[0], goal_edge[1], set())
        if path and len(path) > 1:
            path_edges = list(zip(path[:-1], path[1:]))
            used_edges = [(e, age) for p_edge in path_edges for e, age in entangled_edges if set(p_edge) == set(e)]
            swap_attempts.append({
                'goal': goal_edge,
                'used_edges': used_edges,
                'num_swaps': len(path_edges) - 1
            })

    outcomes = [(state, 1.0, None)]
    for r in range(1, len(swap_attempts) + 1):
        for attempt_combo in combinations(swap_attempts, r):
            used = set()
            if any(e in used or used.add(e) for attempt in attempt_combo for e, _ in attempt['used_edges']):
                continue
            for pattern in product([True, False], repeat=r):
                new_state = []
                goals = []
                for attempt, success in zip(attempt_combo, pattern):
                    goals.append((attempt['goal'], success))
                for edge, age in state:
                    if any(not s and edge in [e for e, _ in a['used_edges']] for a, s in zip(attempt_combo, pattern)):
                        new_state.append((edge, -1))
                    else:
                        new_state.append((edge, age))
                outcomes.append((tuple(sorted(new_state)), 1.0, goals))
    return outcomes

def getAllTransitionProbabilities(state, goalEdges, pSwap, pGen, maxAge):
    transitions = []
    for swap_state, _, goals in generateAllSwappingOutcomes(state, goalEdges, pSwap):
        aged_state = getAgedStates(swap_state, maxAge)
        for final_state, _ in generateAllOutcomes(aged_state, pGen):
            transitions.append((final_state, 1.0, goals))
    return transitions

def generateAllStateTransitions(edges, goalEdges, pSwap, pGen, maxAge):
    return {s: getAllTransitionProbabilities(s, goalEdges, pSwap, pGen, maxAge) for s in getPossibleStates(edges, maxAge)}

def getImmediateReward(goals, counts, t):
    return sum(10 for g, success in goals or [] if success)

# Parameters
edges = [(0, 1), (1, 2), (2, 3), (3, 4)]
goalEdges = [(0, 4)]
pSwap, pGen, maxAge = 1, 1, 3
alpha, gamma, epsilon, n = 0.5, 0.98, 0.2, 3
transitions = generateAllStateTransitions(edges, goalEdges, pSwap, pGen, maxAge)

class QuantumNetworkNStepSARSA:
    def __init__(self, edges, goalEdges, transitions, pSwap, pGen, maxAge, alpha, gamma, epsilon, n):
        self.edges, self.goalEdges, self.transitions = edges, goalEdges, transitions
        self.alpha, self.gamma, self.epsilon, self.n = alpha, gamma, epsilon, n
        self.Q = defaultdict(float)
        self.goal_success_counts = {goal: 0 for goal in goalEdges}
        self.reward_history, self.episode_avg_q_values, self.episode_avg_rewards = [], [], []
        self.edr_history = []
        self.per_goal_edr_history = {goal: [] for goal in goalEdges}

    def choose_action(self, state, train=True):
        ts = self.transitions[state]  # List of possible transitions
        if train and random.random() < self.epsilon:
            # Random action during training
            action = random.choice(ts)
        else:
            # Best action (max Q-value)
            action = max(ts, key=lambda t: self.Q[(state, tuple(t[0]))])  # Convert action to tuple
        return action  # Return the full action tuple (state, action, reward)

    def train(self, total_steps=10000):
        state = tuple((e, -1) for e in self.edges)
        self.goal_success_counts = {goal: 0 for goal in self.goalEdges}
        buffer = deque()
        action = self.choose_action(state)
        total_timesteps = 1

        for t in range(total_steps):
            next_state, _, goals = action  # Unpack correctly
            reward = getImmediateReward(goals, self.goal_success_counts, total_timesteps)
            if goals:
                for g, s in goals:
                    if s:
                        self.goal_success_counts[g] += 1

            print(f"Step {t}: State = {state}\n  Action = {action}\n  Reward = {reward}\n  Q-value before = {self.Q[(state, tuple(action[0]))]:.4f}")
            buffer.append((state, tuple(action), reward))
            state = next_state
            action = self.choose_action(state)
            total_timesteps += 1

            tau = t - self.n + 1
            if tau >= 0:
                G = sum((self.gamma ** (i - tau)) * buffer[i][2] for i in range(tau, min(tau + self.n, len(buffer))))
                if tau + self.n < len(buffer):
                    s_n, a_n, _ = buffer[tau + self.n]
                    G += (self.gamma ** self.n) * self.Q[(s_n, a_n)]
                s_tau, a_tau, _ = buffer.popleft()
                old_q = self.Q[(s_tau, a_tau)]
                self.Q[(s_tau, a_tau)] += self.alpha * (G - old_q)
                print(f"  G = {G:.4f}, Updated Q = {self.Q[(s_tau, a_tau)]:.4f}")

            if (t + 1) % 100 == 0:
                avg_q = np.mean(list(self.Q.values()))
                self.reward_history.append(reward)
                self.episode_avg_q_values.append(avg_q)
                if len(self.reward_history) >= 100:
                    self.episode_avg_rewards.append(np.mean(self.reward_history[-100:]))
                edrs = [self.goal_success_counts[g] / max(1, total_timesteps) for g in self.goalEdges]
                self.edr_history.append(np.mean(edrs))
                for g in self.goalEdges:
                    self.per_goal_edr_history[g].append(self.goal_success_counts[g] / max(1, total_timesteps))

    def plot_results(self):
        plt.figure(figsize=(18, 5))
        plt.subplot(1, 3, 1)
        plt.plot(self.reward_history, label='Reward')
        plt.plot(self.episode_avg_rewards, label='100-step avg')
        plt.title('Reward over Time')
        plt.xlabel('Steps (x100)')
        plt.ylabel('Reward')
        plt.legend()
        plt.grid()

        plt.subplot(1, 3, 2)
        plt.plot(self.episode_avg_q_values)
        plt.title('Average Q-value over Time')
        plt.xlabel('Steps (x100)')
        plt.ylabel('Avg Q-value')
        plt.grid()

        plt.subplot(1, 3, 3)
        for goal in sorted(self.goalEdges):
            plt.plot(self.per_goal_edr_history[goal], label=f"EDR {goal}")
        plt.title('Per-Goal Estimated Delivery Rate (EDR)')
        plt.xlabel('Steps (x100)')
        plt.ylabel('EDR')
        plt.legend()
        plt.grid()

        plt.tight_layout()
        plt.show()

# Running the agent training
agent = QuantumNetworkNStepSARSA(edges, goalEdges, transitions, pSwap, pGen, maxAge, alpha, gamma, epsilon, n)
agent.train(total_steps=10000)
agent.plot_results()
# Out:
# Step 0: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
# Step 1: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
# Step 2: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 3: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 4: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 5: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 6: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 7: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 3), ((1, 2), 1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 8: State = (((0, 1), 3), ((1, 2), 1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 9: State = (((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 10: State = (((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 11: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 12: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 13: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 14: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 15: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 16: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 17: State = (((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), 1))
#   Action = ((((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 18: State = (((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), 2))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 19: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 20: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 21: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 22: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 2), ((1, 2), 2), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 23: State = (((0, 1), 2), ((1, 2), 2), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 3), ((1, 2), 3), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 24: State = (((0, 1), 3), ((1, 2), 3), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 25: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 26: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 27: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 28: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 29: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 30: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 31: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), 1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 32: State = (((0, 1), 3), ((1, 2), 1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 33: State = (((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 34: State = (((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 35: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 36: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 37: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 38: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 39: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 40: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 41: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 42: State = (((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 43: State = (((0, 1), -1), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 3), ((2, 3), 3), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 44: State = (((0, 1), -1), ((1, 2), 3), ((2, 3), 3), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 45: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 46: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 47: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 48: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 49: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 50: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 51: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 52: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 53: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 54: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 55: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 56: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 57: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 58: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 59: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 60: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 61: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 62: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 63: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 64: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 65: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 66: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 67: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 68: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 69: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 70: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 71: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 72: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 73: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 74: State = (((0, 1), -1), ((1, 2), 1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 75: State = (((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 76: State = (((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 77: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 78: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 79: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), 2), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 80: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), 2), ((3, 4), -1))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 81: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 82: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 83: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 84: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 85: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 86: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 87: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 88: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 89: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 90: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 91: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 1), ((2, 3), 2), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 92: State = (((0, 1), -1), ((1, 2), 1), ((2, 3), 2), ((3, 4), 1))
#   Action = ((((0, 1), 1), ((1, 2), 2), ((2, 3), 3), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 93: State = (((0, 1), 1), ((1, 2), 2), ((2, 3), 3), ((3, 4), 2))
#   Action = ((((0, 1), 2), ((1, 2), 3), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 94: State = (((0, 1), 2), ((1, 2), 3), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 95: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 96: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 97: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 98: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 99: State = (((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 100: State = (((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 101: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 102: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 103: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 104: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 105: State = (((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), 2), ((2, 3), 2), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 106: State = (((0, 1), 1), ((1, 2), 2), ((2, 3), 2), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), 3), ((2, 3), 3), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 107: State = (((0, 1), 2), ((1, 2), 3), ((2, 3), 3), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 108: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 109: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 110: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 111: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 112: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 113: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 114: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 115: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 116: State = (((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1))
#   Action = ((((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 117: State = (((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 118: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 119: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 120: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 121: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 122: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 123: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 124: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 125: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 126: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 127: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 128: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 129: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 130: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 131: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 132: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 133: State = (((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), 2), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 134: State = (((0, 1), -1), ((1, 2), 2), ((2, 3), 2), ((3, 4), 2))
#   Action = ((((0, 1), 1), ((1, 2), 3), ((2, 3), 3), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 135: State = (((0, 1), 1), ((1, 2), 3), ((2, 3), 3), ((3, 4), 3))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 136: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 137: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 138: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 139: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 140: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 141: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 142: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), 2), ((2, 3), 1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 143: State = (((0, 1), 2), ((1, 2), 2), ((2, 3), 1), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), 3), ((2, 3), 2), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 144: State = (((0, 1), 3), ((1, 2), 3), ((2, 3), 2), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 145: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 3), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 146: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 147: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 148: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 149: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 150: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 151: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 152: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 153: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 154: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 155: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 156: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 157: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 158: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), 1), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 159: State = (((0, 1), -1), ((1, 2), 1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 160: State = (((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 161: State = (((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 162: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 163: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 164: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 165: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 166: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 167: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 168: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 169: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 170: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 171: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 172: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 173: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 174: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 175: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 176: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 177: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 178: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 179: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 180: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 181: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), 2), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 182: State = (((0, 1), 2), ((1, 2), 2), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), 3), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 183: State = (((0, 1), 3), ((1, 2), 3), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 184: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 185: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 186: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 187: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 188: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 189: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 190: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 191: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 192: State = (((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 193: State = (((0, 1), -1), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 3), ((2, 3), 3), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 194: State = (((0, 1), -1), ((1, 2), 3), ((2, 3), 3), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 195: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 196: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 197: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 198: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 199: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 200: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 201: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 202: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 203: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 204: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 205: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 206: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), 1), ((2, 3), 1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 207: State = (((0, 1), 3), ((1, 2), 1), ((2, 3), 1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 208: State = (((0, 1), -1), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 3), ((2, 3), 3), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 209: State = (((0, 1), -1), ((1, 2), 3), ((2, 3), 3), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 210: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 211: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 212: State = (((0, 1), -1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), 2), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# ...
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 371: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 372: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 373: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 374: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 375: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 376: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 377: State = (((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 378: State = (((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 379: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 380: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 381: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 382: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 383: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), -1))
#   Action = ((((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 384: State = (((0, 1), 2), ((1, 2), 2), ((2, 3), 2), ((3, 4), -1))
#   Action = ((((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 385: State = (((0, 1), 3), ((1, 2), 3), ((2, 3), 3), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 386: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 387: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 388: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 389: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 390: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 391: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 392: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 393: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 394: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 395: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 396: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 397: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 398: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 399: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 400: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 401: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 402: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 403: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 404: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 405: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 406: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 407: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 408: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 409: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 410: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 411: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 412: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 413: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 414: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 415: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 416: State = (((0, 1), -1), ((1, 2), 1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 417: State = (((0, 1), -1), ((1, 2), 2), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 418: State = (((0, 1), -1), ((1, 2), 3), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 419: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 420: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), 3))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 421: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 422: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 423: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 424: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 425: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 426: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 427: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 428: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 429: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 430: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 431: State = (((0, 1), -1), ((1, 2), -1), ((2, 3), -1), ((3, 4), -1))
#   Action = ((((0, 1), 1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 432: State = (((0, 1), 1), ((1, 2), -1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 433: State = (((0, 1), 2), ((1, 2), -1), ((2, 3), 2), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 434: State = (((0, 1), 3), ((1, 2), -1), ((2, 3), 3), ((3, 4), 3))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 435: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), 1), ((3, 4), 1))
#   Action = ((((0, 1), 1), ((1, 2), 1), ((2, 3), -1), ((3, 4), 1)), 1.0, [((0, 4), False)])
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 436: State = (((0, 1), 1), ((1, 2), 1), ((2, 3), -1), ((3, 4), 1))
#   Action = ((((0, 1), 2), ((1, 2), 2), ((2, 3), -1), ((3, 4), 2)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
#   G = 0.0000, Updated Q = 0.0000
# Step 437: State = (((0, 1), 2), ((1, 2), 2), ((2, 3), -1), ((3, 4), 2))
#   Action = ((((0, 1), 3), ((1, 2), 3), ((2, 3), -1), ((3, 4), 3)), 1.0, None)
#   Reward = 0
#   Q-value before = 0.0000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 197
#     195 # Running the agent training
#     196 agent = QuantumNetworkNStepSARSA(edges, goalEdges, transitions, pSwap, pGen, maxAge, alpha, gamma, epsilon, n)
# --> 197 agent.train(total_steps=10000)
#     198 agent.plot_results()
#
# Cell In[27], line 150, in QuantumNetworkNStepSARSA.train(self, total_steps)
#     148     G += (self.gamma ** self.n) * self.Q[(s_n, a_n)]
#     149 s_tau, a_tau, _ = buffer.popleft()
# --> 150 old_q = self.Q[(s_tau, a_tau)]
#     151 self.Q[(s_tau, a_tau)] += self.alpha * (G - old_q)
#     152 print(f"  G = {G:.4f}, Updated Q = {self.Q[(s_tau, a_tau)]:.4f}")
#
# TypeError: unhashable type: 'list'
