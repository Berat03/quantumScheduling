# %% [markdown]
# # Q-Learning

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np
import math
import random
from itertools import product, combinations

# %%
def getPossibleStates(edges, max_age):
    """
    Returns: list of states, where each state is a tuple of ((edge), age)
    """
    sorted_edges = sorted(tuple(sorted(e)) for e in edges)
    possible_ages = [-1] + list(range(1, max_age + 1))

    all_states = [
        tuple(zip(sorted_edges, age_combo))
        for age_combo in product(possible_ages, repeat=len(sorted_edges))
    ]

    return all_states

def getAgedStates(state, maxAge):
    """
    Returns:
        New state as a tuple of ((edge), age) pairs
    """
    new_state = []
    for edge, age in state:
        if age == -1:
            new_state.append((edge, -1))  # not entangled
        else:
            new_age = age + 1
            if new_age <= maxAge:
                new_state.append((edge, new_age))
            else:
                new_state.append((edge, -1))  # entanglement expired

    return tuple(sorted(new_state))


def generateAllOutcomes(state, pGen):
    empty_edges = [edge for edge, age in state if age == -1]
    outcomes = []

    for pattern in product([0, 1], repeat=len(empty_edges)):
        prob = 1.0
        new_state = []

        # First, update the empty edges based on entanglement outcomes
        outcome_map = {}
        for (edge, outcome) in zip(empty_edges, pattern):
            if outcome:
                prob *= pGen
                outcome_map[edge] = 1
            else:
                prob *= (1 - pGen)
                outcome_map[edge] = -1

        # Now build the full new state
        for edge, age in state:
            if edge in outcome_map:
                new_state.append((edge, outcome_map[edge]))
            else:
                new_state.append((edge, age))  # unchanged

        outcomes.append((tuple(sorted(new_state)), prob))

    return outcomes

def generateAllSwappingOutcomes(state, goalEdges, pSwap):
    """
    Generate all possible outcomes from swapping operations or doing nothing.
    Can attempt multiple non-overlapping swaps simultaneously.
    """
    def find_path(current, target, visited):
        if current == target:
            return [current]
        visited.add(current)
        for next_node in graph.get(current, []):
            if next_node not in visited:
                path = find_path(next_node, target, visited)
                if path:
                    return [current] + path
        return None

    # First find all possible individual swap attempts
    swap_attempts = []
    entangled_edges = [(edge, age) for edge, age in state if age > 0]
    
    # Create graph once for all path finding
    graph = {}
    for (edge, _) in entangled_edges:
        if edge[0] not in graph: graph[edge[0]] = []
        if edge[1] not in graph: graph[edge[1]] = []
        graph[edge[0]].append(edge[1])
        graph[edge[1]].append(edge[0])
    
    # Find all possible paths for each goal
    for goal_edge in goalEdges:
        start, end = goal_edge
        path = find_path(start, end, set())
        
        if path and len(path) > 1:
            path_edges = list(zip(path[:-1], path[1:]))
            used_edges = []
            for p_edge in path_edges:
                for e, age in entangled_edges:
                    if (e[0] == p_edge[0] and e[1] == p_edge[1]) or \
                       (e[0] == p_edge[1] and e[1] == p_edge[0]):
                        used_edges.append((e, age))
            
            swap_attempts.append({
                'goal': goal_edge,
                'used_edges': used_edges,
                'num_swaps': len(path_edges) - 1
            })
    
    outcomes = []
    
    # Case 1: Do nothing
    outcomes.append((state, 1.0, None))
    
    # Case 2: Try all possible combinations of non-overlapping swaps
    for r in range(1, len(swap_attempts) + 1):
        for attempt_combo in combinations(swap_attempts, r):
            # Check if attempts are compatible (don't share edges)
            all_used_edges = set()
            edge_overlap = False
            for attempt in attempt_combo:
                attempt_edges = set(e for e, _ in attempt['used_edges'])
                if any(e in all_used_edges for e in attempt_edges):
                    edge_overlap = True
                    break
                all_used_edges.update(attempt_edges)
            
            if edge_overlap:
                continue
                
            # Generate all success/failure combinations for this set of attempts
            for success_pattern in product([True, False], repeat=len(attempt_combo)):
                new_state = []
                total_prob = 1.0
                achieved_goals = []
                
                # Calculate probability and track achieved goals
                for attempt, succeeded in zip(attempt_combo, success_pattern):
                    prob = pSwap ** attempt['num_swaps'] if succeeded else \
                          (1 - pSwap ** attempt['num_swaps'])
                    total_prob *= prob
                    if succeeded:
                        achieved_goals.append((attempt['goal'], True))
                    else:
                        achieved_goals.append((attempt['goal'], False))
                
                # Create new state
                for edge, age in state:
                    if any(edge == e for attempt in attempt_combo 
                          for e, _ in attempt['used_edges']):
                        new_state.append((edge, -1))  # Used edges become unentangled
                    else:
                        new_state.append((edge, age))  # Other edges remain unchanged
                
                new_state = tuple(sorted(new_state))
                outcomes.append((new_state, total_prob, achieved_goals))
    
    return outcomes

def getAllTransitionProbabilities(state, goalEdges, pSwap, pGen, maxAge):
    """
    Returns:
        List of (new_state, probability, achieved_goals) tuples
    """
    all_transitions = []
    
    # Get all possible swap action outcomes
    swap_outcomes = generateAllSwappingOutcomes(state, goalEdges, pSwap)
    
    # For each swap outcome, generate all possible generation outcomes
    for swap_state, swap_prob, achieved_goals in swap_outcomes:
        # Skip if swap probability is 0
        if swap_prob == 0:
            continue
            
        # First age the state
        aged_state = getAgedStates(swap_state, maxAge)
        
        # Then get all possible generation outcomes
        gen_outcomes = generateAllOutcomes(aged_state, pGen)
        
        # Combine the probabilities and add to transitions
        for final_state, gen_prob in gen_outcomes:
            # Skip if either probability is 0
            if gen_prob == 0:
                continue
                
            all_transitions.append((
                final_state,
                swap_prob * gen_prob,
                achieved_goals
            ))
    
    return all_transitions

def generateAllStateTransitions(edges, goalEdges, pSwap, pGen, maxAge):
    """
    Returns:
        Dictionary mapping state -> list of (next_state, prob, achieved_goals)
    """
    # Get all possible states
    all_states = getPossibleStates(edges, maxAge)
    transitions = {}
    
    # For each state, calculate all possible transitions
    for state in all_states:
        transitions[state] = getAllTransitionProbabilities(state, goalEdges, pSwap, pGen, maxAge)
    
    return transitions

# %%
def getImmediateReward(achieved_goals, goal_success_counts, total_timesteps):
    if achieved_goals is None:
        return 0

    total_reward = 0
    for goal_edge, success in achieved_goals:
        if success:
            start, end = goal_edge
            num_edges = abs(end - start)
            instant_rate = pSwap ** (num_edges - 1)

            edr = max(0.0001, goal_success_counts[goal_edge] / max(1, total_timesteps))

            if instant_rate > 0 and edr > 0:
                total_reward += instant_rate / edr
    return total_reward

class QuantumNetworkQLearning:
    def __init__(self, edges, goalEdges, all_transitions, pSwap, pGen, maxAge):
        self.edges = edges
        self.goalEdges = goalEdges
        self.all_transitions = all_transitions
        self.pSwap = pSwap
        self.pGen = pGen
        self.maxAge = maxAge
        
        # Q-learning parameters
        self.alpha = 0.1
        self.gamma = 0.98
        self.epsilon = 0.3
        
        # Initialize Q-table using your transition structure
        self.Q = defaultdict(lambda: defaultdict(float))
        
        # Tracking variables
        self.goal_success_counts = {goal: 0 for goal in goalEdges}
        self.edr_history = {goal: [] for goal in goalEdges}
        self.reward_history = []
        
        # New convergence tracking variables
        self.episode_avg_q_values = []
        self.episode_avg_rewards = []
        self.episode_edrs = {goal: [] for goal in goalEdges}
        
    def group_transitions_by_action(self, state_transitions):
        """Group transitions by the attempted goals, ignoring success/failure"""
        action_groups = defaultdict(list)
        
        for next_state, prob, achieved_goals in state_transitions:
            if achieved_goals is None:
                action_key = None
            else:
                action_key = tuple(sorted(goal for goal, _ in achieved_goals))
            action_groups[action_key].append((next_state, prob, achieved_goals))
        
        return action_groups
    
    def choose_action(self, state, training=True):
        """Choose action using epsilon-greedy"""
        action_groups = self.group_transitions_by_action(self.all_transitions[state])
        
        if training and random.random() < self.epsilon:
            # Explore: random action group
            action_keys = list(action_groups.keys())
            chosen_key = random.choice(action_keys)
            transitions = action_groups[chosen_key]
        else:
            # Exploit: best action group based on Q-values
            best_value = float('-inf')
            best_transitions = None
            
            for action_key, transitions in action_groups.items():
                # Get average Q-value for this action group
                q_value = np.mean([self.Q[state][next_state] for next_state, _, _ in transitions])
                if q_value > best_value:
                    best_value = q_value
                    best_transitions = transitions
            
            transitions = best_transitions
        
        # Choose specific transition based on probabilities
        probs = [t[1] for t in transitions]
        return random.choices(transitions, weights=probs)[0]
    
    def train(self, num_episodes=1000, max_steps=100):
        window_size = 100  # For moving averages
        
        for episode in range(num_episodes):
            state = tuple((edge, -1) for edge in self.edges)
            episode_reward = 0
            total_timesteps = 1
            episode_q_values = []
            self.goal_success_counts = {goal: 0 for goal in self.goalEdges}
            
            for step in range(max_steps):
                # Choose and execute action
                next_state, prob, achieved_goals = self.choose_action(state, training=True)
                
                # Update goal successes
                if achieved_goals is not None:
                    for goal_edge, success in achieved_goals:
                        if success:
                            self.goal_success_counts[goal_edge] += 1
                
                # Get reward
                reward = getImmediateReward(achieved_goals, self.goal_success_counts, total_timesteps)
                episode_reward += reward
                
                # Q-learning update
                old_q = self.Q[state][next_state]
                next_q = max([self.Q[next_state][ns] for ns, _, _ in self.all_transitions[next_state]], default=0)
                self.Q[state][next_state] = old_q + self.alpha * (reward + self.gamma * next_q - old_q)
                
                # Track Q-values for convergence
                episode_q_values.append(self.Q[state][next_state])
                
                # Update EDR tracking
                for goal in self.goalEdges:
                    current_edr = self.goal_success_counts[goal] / total_timesteps
                    if episode == num_episodes - 1:  # Only track last episode
                        self.edr_history[goal].append(current_edr)
                
                # Transition
                state = next_state
                total_timesteps += 1
            
            # Store episode metrics
            self.reward_history.append(episode_reward)
            self.episode_avg_q_values.append(np.mean(episode_q_values))
            
            # Store EDRs for each goal at the end of episode
            for goal in self.goalEdges:
                self.episode_edrs[goal].append(self.goal_success_counts[goal] / total_timesteps)
            
            # Calculate moving averages for reward
            if len(self.reward_history) >= window_size:
                avg_reward = np.mean(self.reward_history[-window_size:])
                self.episode_avg_rewards.append(avg_reward)
            
            if (episode + 1) % 100 == 0:
                avg_reward = np.mean(self.reward_history[-100:])
                print(f"Episode {episode + 1}, Average Reward (last 100): {avg_reward:.2f}")
                print("Current EDRs:", {g: self.goal_success_counts[g]/total_timesteps for g in self.goalEdges})
    
    def plot_results(self):
        fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))
        
        # Plot 1: EDR evolution (last episode)
        for goal, edr_values in self.edr_history.items():
            ax1.plot(range(len(edr_values)), edr_values, label=f'Goal {goal}')
        ax1.set_xlabel('Step')
        ax1.set_ylabel('EDR')
        ax1.set_title('EDR Evolution (Last Episode)')
        ax1.grid(True)
        ax1.legend()
        ax1.set_ylim(0, 1)
        
        # Plot 2: Reward history
        ax2.plot(self.reward_history, alpha=0.3, label='Raw')
        if len(self.episode_avg_rewards) > 0:  # Only plot if we have moving averages
            ax2.plot(range(99, len(self.episode_avg_rewards) + 99), 
                    self.episode_avg_rewards, 
                    label='100-episode moving avg')
        ax2.set_xlabel('Episode')
        ax2.set_ylabel('Total Reward')
        ax2.set_title('Training Progress (Reward)')
        ax2.grid(True)
        ax2.legend()
        
        # Plot 3: Average Q-value evolution
        ax3.plot(self.episode_avg_q_values)
        ax3.set_xlabel('Episode')
        ax3.set_ylabel('Average Q-value')
        ax3.set_title('Q-value Convergence')
        ax3.grid(True)
        
        # Plot 4: EDR evolution across episodes
        for goal, edr_values in self.episode_edrs.items():
            ax4.plot(range(len(edr_values)), edr_values, label=f'Goal {goal}')
        ax4.set_xlabel('Episode')
        ax4.set_ylabel('EDR')
        ax4.set_title('EDR Evolution Across Episodes')
        ax4.grid(True)
        ax4.legend()
        ax4.set_ylim(0, 1)
        
        plt.tight_layout()
        plt.show()
        
        # Print convergence statistics
        print("\n=== Convergence Statistics ===")
        window_sizes = [100, 500, 1000]
        for window in window_sizes:
            if len(self.reward_history) >= window:
                print(f"\nLast {window} episodes:")
                print(f"Average reward: {np.mean(self.reward_history[-window:]):.2f}")
                print(f"Reward std dev: {np.std(self.reward_history[-window:]):.2f}")
                print(f"Average Q-value: {np.mean(self.episode_avg_q_values[-window:]):.2f}")
                print("\nFinal EDRs:")
                for goal in self.goalEdges:
                    print(f"Goal {goal}: {np.mean(self.episode_edrs[goal][-window:]):.4f}")

# Example usage
edges = [(0, 1), (1, 2), (2, 3), (3,4)]
goalEdges = [(0, 2), (1, 4)]
pSwap = 0.8
pGen = 0.8
maxAge = 2

# First generate all transitions using your existing code
all_transitions = generateAllStateTransitions(edges, goalEdges, pSwap, pGen, maxAge)

# Create and train agent
agent = QuantumNetworkQLearning(
    edges=edges,
    goalEdges=goalEdges,
    all_transitions=all_transitions,
    pSwap=pSwap,
    pGen=pGen,
    maxAge=maxAge
)
agent.train(num_episodes=50000, max_steps=1000)
agent.plot_results()

# Print final statistics
print("\n=== Final Statistics ===")
print(f"Parameters: pSwap={pSwap}, pGen={pGen}, maxAge={maxAge}")
print(f"Network: edges={edges}, goals={goalEdges}")

print("\nFinal EDRs (Last Episode):")
total_timesteps = len(next(iter(agent.edr_history.values())))
for goal in agent.goalEdges:
    final_edr = agent.goal_success_counts[goal] / total_timesteps
    print(f"Goal {goal}: EDR = {final_edr:.6f}")
    print(f"  - Successes: {agent.goal_success_counts[goal]}")  # Changed this line
    print(f"  - Total timesteps: {total_timesteps}")

print(f"\nFinal Average Reward (last 100 episodes): {np.mean(agent.reward_history[-100:]):.4f}")

from manualNstep import simulate_policy

goal_success_counts, total_timesteps, edr_history = simulate_policy(
    Q_table=Q,  # Your trained qTable object
    edges=initialEdges,
    goal_edges=goalEdges,
    p_swap=pSwap,
    p_gen=pGen,
    max_age=maxAge,
    num_steps=10000
)
# Out:
# Episode 100, Average Reward (last 100): 1442.56
# Current EDRs: {(0, 2): 0.18581418581418582, (1, 4): 0.08191808191808192}
# Episode 200, Average Reward (last 100): 1424.18
# Current EDRs: {(0, 2): 0.18981018981018982, (1, 4): 0.07392607392607392}
# Episode 300, Average Reward (last 100): 1433.00
# Current EDRs: {(0, 2): 0.18281718281718282, (1, 4): 0.08691308691308691}
# Episode 400, Average Reward (last 100): 1433.74
# Current EDRs: {(0, 2): 0.2217782217782218, (1, 4): 0.16583416583416583}
# Episode 500, Average Reward (last 100): 1434.53
# Current EDRs: {(0, 2): 0.2047952047952048, (1, 4): 0.13586413586413587}
# Episode 600, Average Reward (last 100): 1437.10
# Current EDRs: {(0, 2): 0.22977022977022976, (1, 4): 0.15284715284715283}
# Episode 700, Average Reward (last 100): 1439.21
# Current EDRs: {(0, 2): 0.21578421578421578, (1, 4): 0.16083916083916083}
# Episode 800, Average Reward (last 100): 1451.40
# Current EDRs: {(0, 2): 0.2177822177822178, (1, 4): 0.16283716283716285}
# Episode 900, Average Reward (last 100): 1450.30
# Current EDRs: {(0, 2): 0.2597402597402597, (1, 4): 0.13886113886113885}
# Episode 1000, Average Reward (last 100): 1444.53
# Current EDRs: {(0, 2): 0.25274725274725274, (1, 4): 0.15684315684315683}
# Episode 1100, Average Reward (last 100): 1451.83
# Current EDRs: {(0, 2): 0.25374625374625376, (1, 4): 0.15084915084915085}
# Episode 1200, Average Reward (last 100): 1438.68
# Current EDRs: {(0, 2): 0.26373626373626374, (1, 4): 0.15984015984015984}
# Episode 1300, Average Reward (last 100): 1438.39
# Current EDRs: {(0, 2): 0.24375624375624375, (1, 4): 0.15184815184815184}
# Episode 1400, Average Reward (last 100): 1450.22
# Current EDRs: {(0, 2): 0.2857142857142857, (1, 4): 0.13986013986013987}
# Episode 1500, Average Reward (last 100): 1447.93
# Current EDRs: {(0, 2): 0.24775224775224775, (1, 4): 0.16983016983016982}
# Episode 1600, Average Reward (last 100): 1427.05
# Current EDRs: {(0, 2): 0.27172827172827174, (1, 4): 0.13486513486513488}
# Episode 1700, Average Reward (last 100): 1446.22
# Current EDRs: {(0, 2): 0.2137862137862138, (1, 4): 0.16783216783216784}
# Episode 1800, Average Reward (last 100): 1448.33
# Current EDRs: {(0, 2): 0.21478521478521478, (1, 4): 0.14685314685314685}
# Episode 1900, Average Reward (last 100): 1440.75
# Current EDRs: {(0, 2): 0.24975024975024976, (1, 4): 0.15984015984015984}
# Episode 2000, Average Reward (last 100): 1439.64
# Current EDRs: {(0, 2): 0.2597402597402597, (1, 4): 0.15684315684315683}
# Episode 2100, Average Reward (last 100): 1438.61
# Current EDRs: {(0, 2): 0.25274725274725274, (1, 4): 0.13986013986013987}
# Episode 2200, Average Reward (last 100): 1449.77
# Current EDRs: {(0, 2): 0.25274725274725274, (1, 4): 0.15284715284715283}
# Episode 2300, Average Reward (last 100): 1453.42
# Current EDRs: {(0, 2): 0.24075924075924077, (1, 4): 0.13386613386613386}
# Episode 2400, Average Reward (last 100): 1446.52
# Current EDRs: {(0, 2): 0.2727272727272727, (1, 4): 0.14585414585414586}
# Episode 2500, Average Reward (last 100): 1450.37
# Current EDRs: {(0, 2): 0.2807192807192807, (1, 4): 0.14585414585414586}
# Episode 2600, Average Reward (last 100): 1444.95
# Current EDRs: {(0, 2): 0.26973026973026976, (1, 4): 0.14685314685314685}
# Episode 2700, Average Reward (last 100): 1439.50
# Current EDRs: {(0, 2): 0.26573426573426573, (1, 4): 0.15084915084915085}
# Episode 2800, Average Reward (last 100): 1444.61
# Current EDRs: {(0, 2): 0.26173826173826176, (1, 4): 0.17182817182817184}
# Episode 2900, Average Reward (last 100): 1443.61
# Current EDRs: {(0, 2): 0.2837162837162837, (1, 4): 0.14385614385614387}
# Episode 3000, Average Reward (last 100): 1442.57
# Current EDRs: {(0, 2): 0.2907092907092907, (1, 4): 0.12987012987012986}
# Episode 3100, Average Reward (last 100): 1454.49
# Current EDRs: {(0, 2): 0.23576423576423577, (1, 4): 0.17482517482517482}
# Episode 3200, Average Reward (last 100): 1444.95
# Current EDRs: {(0, 2): 0.25874125874125875, (1, 4): 0.1848151848151848}
# Episode 3300, Average Reward (last 100): 1433.45
# Current EDRs: {(0, 2): 0.2997002997002997, (1, 4): 0.16383616383616384}
# Episode 3400, Average Reward (last 100): 1435.03
# Current EDRs: {(0, 2): 0.2647352647352647, (1, 4): 0.15784215784215785}
# Episode 3500, Average Reward (last 100): 1447.28
# Current EDRs: {(0, 2): 0.2857142857142857, (1, 4): 0.15484515484515485}
# Episode 3600, Average Reward (last 100): 1463.28
# Current EDRs: {(0, 2): 0.2777222777222777, (1, 4): 0.16683316683316685}
# Episode 3700, Average Reward (last 100): 1453.36
# Current EDRs: {(0, 2): 0.2817182817182817, (1, 4): 0.17682317682317683}
# Episode 3800, Average Reward (last 100): 1450.62
# Current EDRs: {(0, 2): 0.25574425574425574, (1, 4): 0.17782217782217782}
# Episode 3900, Average Reward (last 100): 1439.23
# Current EDRs: {(0, 2): 0.26873126873126874, (1, 4): 0.16283716283716285}
# Episode 4000, Average Reward (last 100): 1442.77
# Current EDRs: {(0, 2): 0.2677322677322677, (1, 4): 0.16083916083916083}
# Episode 4100, Average Reward (last 100): 1443.28
# Current EDRs: {(0, 2): 0.2967032967032967, (1, 4): 0.17182817182817184}
# Episode 4200, Average Reward (last 100): 1447.34
# Current EDRs: {(0, 2): 0.2837162837162837, (1, 4): 0.16983016983016982}
# Episode 4300, Average Reward (last 100): 1442.71
# Current EDRs: {(0, 2): 0.2727272727272727, (1, 4): 0.1968031968031968}
# Episode 4400, Average Reward (last 100): 1450.46
# Current EDRs: {(0, 2): 0.26873126873126874, (1, 4): 0.17482517482517482}
# Episode 4500, Average Reward (last 100): 1447.25
# Current EDRs: {(0, 2): 0.28471528471528473, (1, 4): 0.17782217782217782}
# Episode 4600, Average Reward (last 100): 1454.30
# Current EDRs: {(0, 2): 0.2967032967032967, (1, 4): 0.14785214785214784}
# Episode 4700, Average Reward (last 100): 1447.06
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.14785214785214784}
# Episode 4800, Average Reward (last 100): 1450.87
# Current EDRs: {(0, 2): 0.2707292707292707, (1, 4): 0.16483516483516483}
# Episode 4900, Average Reward (last 100): 1432.94
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.16983016983016982}
# Episode 5000, Average Reward (last 100): 1449.40
# Current EDRs: {(0, 2): 0.26873126873126874, (1, 4): 0.17882117882117882}
# Episode 5100, Average Reward (last 100): 1446.09
# Current EDRs: {(0, 2): 0.2937062937062937, (1, 4): 0.16083916083916083}
# Episode 5200, Average Reward (last 100): 1437.49
# Current EDRs: {(0, 2): 0.28771228771228774, (1, 4): 0.15884115884115885}
# Episode 5300, Average Reward (last 100): 1456.86
# Current EDRs: {(0, 2): 0.2917082917082917, (1, 4): 0.16483516483516483}
# Episode 5400, Average Reward (last 100): 1451.19
# Current EDRs: {(0, 2): 0.3246753246753247, (1, 4): 0.17882117882117882}
# Episode 5500, Average Reward (last 100): 1445.19
# Current EDRs: {(0, 2): 0.2977022977022977, (1, 4): 0.14985014985014986}
# Episode 5600, Average Reward (last 100): 1450.10
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.17082917082917082}
# Episode 5700, Average Reward (last 100): 1445.36
# Current EDRs: {(0, 2): 0.2897102897102897, (1, 4): 0.17082917082917082}
# Episode 5800, Average Reward (last 100): 1458.46
# Current EDRs: {(0, 2): 0.2977022977022977, (1, 4): 0.16483516483516483}
# Episode 5900, Average Reward (last 100): 1436.97
# Current EDRs: {(0, 2): 0.3336663336663337, (1, 4): 0.15384615384615385}
# Episode 6000, Average Reward (last 100): 1443.62
# Current EDRs: {(0, 2): 0.3066933066933067, (1, 4): 0.15184815184815184}
# Episode 6100, Average Reward (last 100): 1439.78
# Current EDRs: {(0, 2): 0.2777222777222777, (1, 4): 0.17882117882117882}
# Episode 6200, Average Reward (last 100): 1437.63
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.17782217782217782}
# Episode 6300, Average Reward (last 100): 1436.92
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.17482517482517482}
# Episode 6400, Average Reward (last 100): 1451.39
# Current EDRs: {(0, 2): 0.2917082917082917, (1, 4): 0.17382617382617382}
# Episode 6500, Average Reward (last 100): 1450.41
# Current EDRs: {(0, 2): 0.29270729270729273, (1, 4): 0.1938061938061938}
# Episode 6600, Average Reward (last 100): 1432.82
# Current EDRs: {(0, 2): 0.31368631368631367, (1, 4): 0.14985014985014986}
# Episode 6700, Average Reward (last 100): 1443.34
# Current EDRs: {(0, 2): 0.2757242757242757, (1, 4): 0.18681318681318682}
# Episode 6800, Average Reward (last 100): 1434.54
# Current EDRs: {(0, 2): 0.32667332667332666, (1, 4): 0.15584415584415584}
# Episode 6900, Average Reward (last 100): 1443.57
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.16683316683316685}
# Episode 7000, Average Reward (last 100): 1441.17
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.18681318681318682}
# Episode 7100, Average Reward (last 100): 1442.62
# Current EDRs: {(0, 2): 0.3206793206793207, (1, 4): 0.17282717282717283}
# Episode 7200, Average Reward (last 100): 1437.43
# Current EDRs: {(0, 2): 0.2937062937062937, (1, 4): 0.17882117882117882}
# Episode 7300, Average Reward (last 100): 1441.15
# Current EDRs: {(0, 2): 0.27172827172827174, (1, 4): 0.1998001998001998}
# Episode 7400, Average Reward (last 100): 1445.03
# Current EDRs: {(0, 2): 0.3076923076923077, (1, 4): 0.17182817182817184}
# Episode 7500, Average Reward (last 100): 1443.89
# Current EDRs: {(0, 2): 0.2997002997002997, (1, 4): 0.19480519480519481}
# Episode 7600, Average Reward (last 100): 1445.05
# Current EDRs: {(0, 2): 0.33666333666333664, (1, 4): 0.17682317682317683}
# Episode 7700, Average Reward (last 100): 1451.33
# Current EDRs: {(0, 2): 0.3036963036963037, (1, 4): 0.1888111888111888}
# Episode 7800, Average Reward (last 100): 1441.11
# Current EDRs: {(0, 2): 0.3206793206793207, (1, 4): 0.17882117882117882}
# Episode 7900, Average Reward (last 100): 1434.93
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.1878121878121878}
# Episode 8000, Average Reward (last 100): 1442.98
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.1888111888111888}
# Episode 8100, Average Reward (last 100): 1443.62
# Current EDRs: {(0, 2): 0.2807192807192807, (1, 4): 0.1978021978021978}
# Episode 8200, Average Reward (last 100): 1445.92
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.1888111888111888}
# Episode 8300, Average Reward (last 100): 1448.97
# Current EDRs: {(0, 2): 0.2777222777222777, (1, 4): 0.1998001998001998}
# Episode 8400, Average Reward (last 100): 1448.81
# Current EDRs: {(0, 2): 0.3176823176823177, (1, 4): 0.16383616383616384}
# Episode 8500, Average Reward (last 100): 1448.84
# Current EDRs: {(0, 2): 0.34665334665334663, (1, 4): 0.14785214785214784}
# Episode 8600, Average Reward (last 100): 1443.44
# Current EDRs: {(0, 2): 0.2997002997002997, (1, 4): 0.17782217782217782}
# Episode 8700, Average Reward (last 100): 1447.62
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.15884115884115885}
# Episode 8800, Average Reward (last 100): 1446.50
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.14785214785214784}
# Episode 8900, Average Reward (last 100): 1446.33
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.17582417582417584}
# Episode 9000, Average Reward (last 100): 1443.79
# Current EDRs: {(0, 2): 0.3246753246753247, (1, 4): 0.17782217782217782}
# Episode 9100, Average Reward (last 100): 1441.20
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.17382617382617382}
# Episode 9200, Average Reward (last 100): 1446.07
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.16083916083916083}
# Episode 9300, Average Reward (last 100): 1447.98
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.17782217782217782}
# Episode 9400, Average Reward (last 100): 1441.52
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.18981018981018982}
# Episode 9500, Average Reward (last 100): 1438.63
# Current EDRs: {(0, 2): 0.33966033966033965, (1, 4): 0.16883116883116883}
# Episode 9600, Average Reward (last 100): 1442.04
# Current EDRs: {(0, 2): 0.2677322677322677, (1, 4): 0.2017982017982018}
# Episode 9700, Average Reward (last 100): 1448.89
# Current EDRs: {(0, 2): 0.26673326673326675, (1, 4): 0.1998001998001998}
# Episode 9800, Average Reward (last 100): 1440.31
# Current EDRs: {(0, 2): 0.3166833166833167, (1, 4): 0.17382617382617382}
# Episode 9900, Average Reward (last 100): 1438.17
# Current EDRs: {(0, 2): 0.3096903096903097, (1, 4): 0.1928071928071928}
# Episode 10000, Average Reward (last 100): 1446.10
# Current EDRs: {(0, 2): 0.2867132867132867, (1, 4): 0.15384615384615385}
# Episode 10100, Average Reward (last 100): 1444.55
# Current EDRs: {(0, 2): 0.2857142857142857, (1, 4): 0.1978021978021978}
# Episode 10200, Average Reward (last 100): 1444.59
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.16683316683316685}
# Episode 10300, Average Reward (last 100): 1445.60
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.16583416583416583}
# Episode 10400, Average Reward (last 100): 1457.48
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.1888111888111888}
# Episode 10500, Average Reward (last 100): 1436.06
# Current EDRs: {(0, 2): 0.31368631368631367, (1, 4): 0.17382617382617382}
# Episode 10600, Average Reward (last 100): 1443.64
# Current EDRs: {(0, 2): 0.2907092907092907, (1, 4): 0.19480519480519481}
# Episode 10700, Average Reward (last 100): 1439.77
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.16983016983016982}
# Episode 10800, Average Reward (last 100): 1442.67
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.14885114885114886}
# Episode 10900, Average Reward (last 100): 1441.53
# Current EDRs: {(0, 2): 0.3256743256743257, (1, 4): 0.15784215784215785}
# Episode 11000, Average Reward (last 100): 1447.94
# Current EDRs: {(0, 2): 0.27972027972027974, (1, 4): 0.17582417582417584}
# Episode 11100, Average Reward (last 100): 1438.89
# Current EDRs: {(0, 2): 0.2887112887112887, (1, 4): 0.17682317682317683}
# Episode 11200, Average Reward (last 100): 1447.97
# Current EDRs: {(0, 2): 0.33666333666333664, (1, 4): 0.15484515484515485}
# Episode 11300, Average Reward (last 100): 1446.97
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.14985014985014986}
# Episode 11400, Average Reward (last 100): 1444.44
# Current EDRs: {(0, 2): 0.2887112887112887, (1, 4): 0.17882117882117882}
# Episode 11500, Average Reward (last 100): 1437.89
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.2127872127872128}
# Episode 11600, Average Reward (last 100): 1446.66
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.16383616383616384}
# Episode 11700, Average Reward (last 100): 1436.90
# Current EDRs: {(0, 2): 0.34265734265734266, (1, 4): 0.15784215784215785}
# Episode 11800, Average Reward (last 100): 1445.41
# Current EDRs: {(0, 2): 0.2837162837162837, (1, 4): 0.1918081918081918}
# Episode 11900, Average Reward (last 100): 1440.43
# Current EDRs: {(0, 2): 0.3306693306693307, (1, 4): 0.18681318681318682}
# Episode 12000, Average Reward (last 100): 1449.76
# Current EDRs: {(0, 2): 0.2957042957042957, (1, 4): 0.15284715284715283}
# Episode 12100, Average Reward (last 100): 1448.40
# Current EDRs: {(0, 2): 0.3156843156843157, (1, 4): 0.18681318681318682}
# Episode 12200, Average Reward (last 100): 1441.86
# Current EDRs: {(0, 2): 0.2857142857142857, (1, 4): 0.18281718281718282}
# Episode 12300, Average Reward (last 100): 1446.67
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.2097902097902098}
# Episode 12400, Average Reward (last 100): 1435.99
# Current EDRs: {(0, 2): 0.26673326673326675, (1, 4): 0.1918081918081918}
# Episode 12500, Average Reward (last 100): 1439.23
# Current EDRs: {(0, 2): 0.28471528471528473, (1, 4): 0.2097902097902098}
# Episode 12600, Average Reward (last 100): 1444.68
# Current EDRs: {(0, 2): 0.2997002997002997, (1, 4): 0.16783216783216784}
# Episode 12700, Average Reward (last 100): 1451.26
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.18181818181818182}
# Episode 12800, Average Reward (last 100): 1444.43
# Current EDRs: {(0, 2): 0.29270729270729273, (1, 4): 0.18681318681318682}
# Episode 12900, Average Reward (last 100): 1441.72
# Current EDRs: {(0, 2): 0.3306693306693307, (1, 4): 0.16783216783216784}
# Episode 13000, Average Reward (last 100): 1446.54
# Current EDRs: {(0, 2): 0.2867132867132867, (1, 4): 0.21678321678321677}
# Episode 13100, Average Reward (last 100): 1449.63
# Current EDRs: {(0, 2): 0.2937062937062937, (1, 4): 0.18181818181818182}
# Episode 13200, Average Reward (last 100): 1451.44
# Current EDRs: {(0, 2): 0.35864135864135865, (1, 4): 0.14585414585414586}
# Episode 13300, Average Reward (last 100): 1437.85
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.15384615384615385}
# Episode 13400, Average Reward (last 100): 1448.44
# Current EDRs: {(0, 2): 0.32667332667332666, (1, 4): 0.17682317682317683}
# Episode 13500, Average Reward (last 100): 1437.35
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.16083916083916083}
# Episode 13600, Average Reward (last 100): 1449.98
# Current EDRs: {(0, 2): 0.32367632367632365, (1, 4): 0.16983016983016982}
# Episode 13700, Average Reward (last 100): 1451.79
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.19080919080919082}
# Episode 13800, Average Reward (last 100): 1443.13
# Current EDRs: {(0, 2): 0.3276723276723277, (1, 4): 0.18181818181818182}
# Episode 13900, Average Reward (last 100): 1452.02
# Current EDRs: {(0, 2): 0.3076923076923077, (1, 4): 0.19080919080919082}
# Episode 14000, Average Reward (last 100): 1449.32
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.18681318681318682}
# Episode 14100, Average Reward (last 100): 1445.38
# Current EDRs: {(0, 2): 0.32167832167832167, (1, 4): 0.17682317682317683}
# Episode 14200, Average Reward (last 100): 1441.62
# Current EDRs: {(0, 2): 0.29270729270729273, (1, 4): 0.22377622377622378}
# Episode 14300, Average Reward (last 100): 1441.49
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.1968031968031968}
# Episode 14400, Average Reward (last 100): 1442.35
# Current EDRs: {(0, 2): 0.3066933066933067, (1, 4): 0.17882117882117882}
# Episode 14500, Average Reward (last 100): 1451.86
# Current EDRs: {(0, 2): 0.3206793206793207, (1, 4): 0.17082917082917082}
# Episode 14600, Average Reward (last 100): 1435.25
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.2097902097902098}
# Episode 14700, Average Reward (last 100): 1445.48
# Current EDRs: {(0, 2): 0.3076923076923077, (1, 4): 0.15584415584415584}
# Episode 14800, Average Reward (last 100): 1451.55
# Current EDRs: {(0, 2): 0.32967032967032966, (1, 4): 0.17282717282717283}
# Episode 14900, Average Reward (last 100): 1443.90
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.1958041958041958}
# Episode 15000, Average Reward (last 100): 1444.80
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.14385614385614387}
# Episode 15100, Average Reward (last 100): 1443.05
# Current EDRs: {(0, 2): 0.32167832167832167, (1, 4): 0.14985014985014986}
# Episode 15200, Average Reward (last 100): 1445.48
# Current EDRs: {(0, 2): 0.2997002997002997, (1, 4): 0.2007992007992008}
# Episode 15300, Average Reward (last 100): 1442.21
# Current EDRs: {(0, 2): 0.2917082917082917, (1, 4): 0.16983016983016982}
# Episode 15400, Average Reward (last 100): 1439.43
# Current EDRs: {(0, 2): 0.3036963036963037, (1, 4): 0.17382617382617382}
# Episode 15500, Average Reward (last 100): 1443.61
# Current EDRs: {(0, 2): 0.3336663336663337, (1, 4): 0.15384615384615385}
# Episode 15600, Average Reward (last 100): 1437.93
# Current EDRs: {(0, 2): 0.31368631368631367, (1, 4): 0.2007992007992008}
# Episode 15700, Average Reward (last 100): 1448.87
# Current EDRs: {(0, 2): 0.34265734265734266, (1, 4): 0.16883116883116883}
# Episode 15800, Average Reward (last 100): 1449.12
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.17882117882117882}
# Episode 15900, Average Reward (last 100): 1441.81
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.17582417582417584}
# Episode 16000, Average Reward (last 100): 1438.58
# Current EDRs: {(0, 2): 0.2977022977022977, (1, 4): 0.1938061938061938}
# Episode 16100, Average Reward (last 100): 1450.91
# Current EDRs: {(0, 2): 0.3036963036963037, (1, 4): 0.1998001998001998}
# Episode 16200, Average Reward (last 100): 1443.83
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.18581418581418582}
# Episode 16300, Average Reward (last 100): 1438.85
# Current EDRs: {(0, 2): 0.2917082917082917, (1, 4): 0.1918081918081918}
# Episode 16400, Average Reward (last 100): 1444.91
# Current EDRs: {(0, 2): 0.3166833166833167, (1, 4): 0.1878121878121878}
# Episode 16500, Average Reward (last 100): 1441.81
# Current EDRs: {(0, 2): 0.3006993006993007, (1, 4): 0.21178821178821178}
# Episode 16600, Average Reward (last 100): 1438.24
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.1958041958041958}
# Episode 16700, Average Reward (last 100): 1453.14
# Current EDRs: {(0, 2): 0.33466533466533466, (1, 4): 0.16783216783216784}
# Episode 16800, Average Reward (last 100): 1441.57
# Current EDRs: {(0, 2): 0.3546453546453546, (1, 4): 0.14685314685314685}
# Episode 16900, Average Reward (last 100): 1439.92
# Current EDRs: {(0, 2): 0.27372627372627373, (1, 4): 0.20679320679320679}
# Episode 17000, Average Reward (last 100): 1446.60
# Current EDRs: {(0, 2): 0.33966033966033965, (1, 4): 0.1958041958041958}
# Episode 17100, Average Reward (last 100): 1443.36
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.19880119880119881}
# Episode 17200, Average Reward (last 100): 1439.31
# Current EDRs: {(0, 2): 0.2807192807192807, (1, 4): 0.20679320679320679}
# Episode 17300, Average Reward (last 100): 1436.25
# Current EDRs: {(0, 2): 0.35064935064935066, (1, 4): 0.1838161838161838}
# Episode 17400, Average Reward (last 100): 1450.88
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.1938061938061938}
# Episode 17500, Average Reward (last 100): 1446.22
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.1918081918081918}
# Episode 17600, Average Reward (last 100): 1437.69
# Current EDRs: {(0, 2): 0.3176823176823177, (1, 4): 0.17782217782217782}
# Episode 17700, Average Reward (last 100): 1438.56
# Current EDRs: {(0, 2): 0.33166833166833165, (1, 4): 0.1798201798201798}
# Episode 17800, Average Reward (last 100): 1427.73
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.1938061938061938}
# Episode 17900, Average Reward (last 100): 1435.88
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.1998001998001998}
# Episode 18000, Average Reward (last 100): 1442.16
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.18581418581418582}
# Episode 18100, Average Reward (last 100): 1445.14
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.1978021978021978}
# Episode 18200, Average Reward (last 100): 1435.93
# Current EDRs: {(0, 2): 0.33466533466533466, (1, 4): 0.15284715284715283}
# Episode 18300, Average Reward (last 100): 1441.03
# Current EDRs: {(0, 2): 0.32167832167832167, (1, 4): 0.18981018981018982}
# Episode 18400, Average Reward (last 100): 1448.40
# Current EDRs: {(0, 2): 0.33166833166833165, (1, 4): 0.17182817182817184}
# Episode 18500, Average Reward (last 100): 1447.83
# Current EDRs: {(0, 2): 0.3046953046953047, (1, 4): 0.18081918081918083}
# Episode 18600, Average Reward (last 100): 1441.20
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.19480519480519481}
# Episode 18700, Average Reward (last 100): 1438.07
# Current EDRs: {(0, 2): 0.2907092907092907, (1, 4): 0.21678321678321677}
# Episode 18800, Average Reward (last 100): 1448.24
# Current EDRs: {(0, 2): 0.3166833166833167, (1, 4): 0.18681318681318682}
# Episode 18900, Average Reward (last 100): 1444.31
# Current EDRs: {(0, 2): 0.2967032967032967, (1, 4): 0.1888111888111888}
# Episode 19000, Average Reward (last 100): 1443.21
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.2097902097902098}
# Episode 19100, Average Reward (last 100): 1442.87
# Current EDRs: {(0, 2): 0.3436563436563437, (1, 4): 0.1848151848151848}
# Episode 19200, Average Reward (last 100): 1441.76
# Current EDRs: {(0, 2): 0.31368631368631367, (1, 4): 0.1918081918081918}
# Episode 19300, Average Reward (last 100): 1442.88
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.20279720279720279}
# Episode 19400, Average Reward (last 100): 1446.29
# Current EDRs: {(0, 2): 0.2887112887112887, (1, 4): 0.2007992007992008}
# Episode 19500, Average Reward (last 100): 1441.20
# Current EDRs: {(0, 2): 0.32667332667332666, (1, 4): 0.17882117882117882}
# Episode 19600, Average Reward (last 100): 1450.66
# Current EDRs: {(0, 2): 0.33166833166833165, (1, 4): 0.18681318681318682}
# Episode 19700, Average Reward (last 100): 1446.92
# Current EDRs: {(0, 2): 0.33466533466533466, (1, 4): 0.16883116883116883}
# Episode 19800, Average Reward (last 100): 1439.99
# Current EDRs: {(0, 2): 0.2967032967032967, (1, 4): 0.16183816183816183}
# Episode 19900, Average Reward (last 100): 1440.50
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.17782217782217782}
# Episode 20000, Average Reward (last 100): 1446.00
# Current EDRs: {(0, 2): 0.33466533466533466, (1, 4): 0.1848151848151848}
# Episode 20100, Average Reward (last 100): 1434.84
# Current EDRs: {(0, 2): 0.3016983016983017, (1, 4): 0.21178821178821178}
# Episode 20200, Average Reward (last 100): 1443.56
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.18681318681318682}
# Episode 20300, Average Reward (last 100): 1442.01
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.2017982017982018}
# Episode 20400, Average Reward (last 100): 1439.67
# Current EDRs: {(0, 2): 0.32367632367632365, (1, 4): 0.1838161838161838}
# Episode 20500, Average Reward (last 100): 1445.05
# Current EDRs: {(0, 2): 0.2987012987012987, (1, 4): 0.1918081918081918}
# Episode 20600, Average Reward (last 100): 1443.50
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.15684315684315683}
# Episode 20700, Average Reward (last 100): 1445.56
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.19880119880119881}
# Episode 20800, Average Reward (last 100): 1440.89
# Current EDRs: {(0, 2): 0.3166833166833167, (1, 4): 0.1918081918081918}
# Episode 20900, Average Reward (last 100): 1433.67
# Current EDRs: {(0, 2): 0.2987012987012987, (1, 4): 0.1938061938061938}
# Episode 21000, Average Reward (last 100): 1439.52
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.16183816183816183}
# Episode 21100, Average Reward (last 100): 1442.66
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.2097902097902098}
# Episode 21200, Average Reward (last 100): 1445.22
# Current EDRs: {(0, 2): 0.2957042957042957, (1, 4): 0.18681318681318682}
# Episode 21300, Average Reward (last 100): 1436.97
# Current EDRs: {(0, 2): 0.2917082917082917, (1, 4): 0.20279720279720279}
# Episode 21400, Average Reward (last 100): 1444.58
# Current EDRs: {(0, 2): 0.3256743256743257, (1, 4): 0.1848151848151848}
# Episode 21500, Average Reward (last 100): 1441.54
# Current EDRs: {(0, 2): 0.3176823176823177, (1, 4): 0.17582417582417584}
# Episode 21600, Average Reward (last 100): 1443.06
# Current EDRs: {(0, 2): 0.3006993006993007, (1, 4): 0.17782217782217782}
# Episode 21700, Average Reward (last 100): 1440.48
# Current EDRs: {(0, 2): 0.3096903096903097, (1, 4): 0.1958041958041958}
# Episode 21800, Average Reward (last 100): 1443.69
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.2097902097902098}
# Episode 21900, Average Reward (last 100): 1440.33
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.1848151848151848}
# Episode 22000, Average Reward (last 100): 1445.83
# Current EDRs: {(0, 2): 0.2777222777222777, (1, 4): 0.1958041958041958}
# Episode 22100, Average Reward (last 100): 1442.06
# Current EDRs: {(0, 2): 0.2987012987012987, (1, 4): 0.18181818181818182}
# Episode 22200, Average Reward (last 100): 1446.24
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.2057942057942058}
# Episode 22300, Average Reward (last 100): 1436.45
# Current EDRs: {(0, 2): 0.3156843156843157, (1, 4): 0.18681318681318682}
# Episode 22400, Average Reward (last 100): 1440.63
# Current EDRs: {(0, 2): 0.35064935064935066, (1, 4): 0.2057942057942058}
# Episode 22500, Average Reward (last 100): 1435.97
# Current EDRs: {(0, 2): 0.3046953046953047, (1, 4): 0.1878121878121878}
# Episode 22600, Average Reward (last 100): 1440.71
# Current EDRs: {(0, 2): 0.32367632367632365, (1, 4): 0.17882117882117882}
# Episode 22700, Average Reward (last 100): 1437.37
# Current EDRs: {(0, 2): 0.35664335664335667, (1, 4): 0.18081918081918083}
# Episode 22800, Average Reward (last 100): 1448.70
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.2047952047952048}
# Episode 22900, Average Reward (last 100): 1439.08
# Current EDRs: {(0, 2): 0.2837162837162837, (1, 4): 0.17682317682317683}
# Episode 23000, Average Reward (last 100): 1448.10
# Current EDRs: {(0, 2): 0.2987012987012987, (1, 4): 0.2007992007992008}
# Episode 23100, Average Reward (last 100): 1450.51
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.1848151848151848}
# Episode 23200, Average Reward (last 100): 1435.13
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.18181818181818182}
# Episode 23300, Average Reward (last 100): 1446.55
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.2057942057942058}
# Episode 23400, Average Reward (last 100): 1445.04
# Current EDRs: {(0, 2): 0.3356643356643357, (1, 4): 0.18181818181818182}
# Episode 23500, Average Reward (last 100): 1432.10
# Current EDRs: {(0, 2): 0.31368631368631367, (1, 4): 0.1918081918081918}
# Episode 23600, Average Reward (last 100): 1442.12
# Current EDRs: {(0, 2): 0.27372627372627373, (1, 4): 0.2137862137862138}
# Episode 23700, Average Reward (last 100): 1440.23
# Current EDRs: {(0, 2): 0.34165834165834164, (1, 4): 0.17682317682317683}
# Episode 23800, Average Reward (last 100): 1441.26
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.18681318681318682}
# Episode 23900, Average Reward (last 100): 1445.57
# Current EDRs: {(0, 2): 0.33666333666333664, (1, 4): 0.1938061938061938}
# Episode 24000, Average Reward (last 100): 1444.07
# Current EDRs: {(0, 2): 0.3036963036963037, (1, 4): 0.2057942057942058}
# Episode 24100, Average Reward (last 100): 1438.84
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.18281718281718282}
# Episode 24200, Average Reward (last 100): 1440.49
# Current EDRs: {(0, 2): 0.3036963036963037, (1, 4): 0.16983016983016982}
# Episode 24300, Average Reward (last 100): 1448.70
# Current EDRs: {(0, 2): 0.34865134865134867, (1, 4): 0.16683316683316685}
# Episode 24400, Average Reward (last 100): 1445.64
# Current EDRs: {(0, 2): 0.3016983016983017, (1, 4): 0.17482517482517482}
# Episode 24500, Average Reward (last 100): 1430.91
# Current EDRs: {(0, 2): 0.32967032967032966, (1, 4): 0.18981018981018982}
# Episode 24600, Average Reward (last 100): 1437.63
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.18681318681318682}
# Episode 24700, Average Reward (last 100): 1447.00
# Current EDRs: {(0, 2): 0.3306693306693307, (1, 4): 0.15784215784215785}
# Episode 24800, Average Reward (last 100): 1438.34
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.1798201798201798}
# Episode 24900, Average Reward (last 100): 1444.61
# Current EDRs: {(0, 2): 0.28771228771228774, (1, 4): 0.1938061938061938}
# Episode 25000, Average Reward (last 100): 1437.06
# Current EDRs: {(0, 2): 0.3246753246753247, (1, 4): 0.1878121878121878}
# Episode 25100, Average Reward (last 100): 1443.19
# Current EDRs: {(0, 2): 0.3016983016983017, (1, 4): 0.19880119880119881}
# Episode 25200, Average Reward (last 100): 1439.61
# Current EDRs: {(0, 2): 0.3096903096903097, (1, 4): 0.19480519480519481}
# Episode 25300, Average Reward (last 100): 1444.35
# Current EDRs: {(0, 2): 0.2907092907092907, (1, 4): 0.2007992007992008}
# Episode 25400, Average Reward (last 100): 1443.74
# Current EDRs: {(0, 2): 0.3306693306693307, (1, 4): 0.18081918081918083}
# Episode 25500, Average Reward (last 100): 1449.10
# Current EDRs: {(0, 2): 0.3246753246753247, (1, 4): 0.1798201798201798}
# Episode 25600, Average Reward (last 100): 1449.34
# Current EDRs: {(0, 2): 0.33466533466533466, (1, 4): 0.1878121878121878}
# Episode 25700, Average Reward (last 100): 1438.60
# Current EDRs: {(0, 2): 0.3016983016983017, (1, 4): 0.1848151848151848}
# Episode 25800, Average Reward (last 100): 1448.13
# Current EDRs: {(0, 2): 0.2937062937062937, (1, 4): 0.17882117882117882}
# Episode 25900, Average Reward (last 100): 1442.01
# Current EDRs: {(0, 2): 0.3276723276723277, (1, 4): 0.19080919080919082}
# Episode 26000, Average Reward (last 100): 1439.91
# Current EDRs: {(0, 2): 0.3256743256743257, (1, 4): 0.2087912087912088}
# Episode 26100, Average Reward (last 100): 1453.32
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.1848151848151848}
# Episode 26200, Average Reward (last 100): 1436.39
# Current EDRs: {(0, 2): 0.3256743256743257, (1, 4): 0.1798201798201798}
# Episode 26300, Average Reward (last 100): 1442.63
# Current EDRs: {(0, 2): 0.3276723276723277, (1, 4): 0.16483516483516483}
# Episode 26400, Average Reward (last 100): 1436.33
# Current EDRs: {(0, 2): 0.2967032967032967, (1, 4): 0.19080919080919082}
# Episode 26500, Average Reward (last 100): 1440.94
# Current EDRs: {(0, 2): 0.2897102897102897, (1, 4): 0.1838161838161838}
# Episode 26600, Average Reward (last 100): 1442.91
# Current EDRs: {(0, 2): 0.2887112887112887, (1, 4): 0.1878121878121878}
# Episode 26700, Average Reward (last 100): 1439.62
# Current EDRs: {(0, 2): 0.3096903096903097, (1, 4): 0.21078921078921078}
# Episode 26800, Average Reward (last 100): 1448.05
# Current EDRs: {(0, 2): 0.3276723276723277, (1, 4): 0.16883116883116883}
# Episode 26900, Average Reward (last 100): 1438.23
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.1958041958041958}
# Episode 27000, Average Reward (last 100): 1438.98
# Current EDRs: {(0, 2): 0.2997002997002997, (1, 4): 0.17582417582417584}
# Episode 27100, Average Reward (last 100): 1442.84
# Current EDRs: {(0, 2): 0.3356643356643357, (1, 4): 0.18181818181818182}
# Episode 27200, Average Reward (last 100): 1447.49
# Current EDRs: {(0, 2): 0.32367632367632365, (1, 4): 0.1928071928071928}
# Episode 27300, Average Reward (last 100): 1441.74
# Current EDRs: {(0, 2): 0.2777222777222777, (1, 4): 0.1848151848151848}
# Episode 27400, Average Reward (last 100): 1447.27
# Current EDRs: {(0, 2): 0.3006993006993007, (1, 4): 0.2177822177822178}
# Episode 27500, Average Reward (last 100): 1448.98
# Current EDRs: {(0, 2): 0.2627372627372627, (1, 4): 0.2037962037962038}
# Episode 27600, Average Reward (last 100): 1443.64
# Current EDRs: {(0, 2): 0.2837162837162837, (1, 4): 0.21078921078921078}
# Episode 27700, Average Reward (last 100): 1443.16
# Current EDRs: {(0, 2): 0.32667332667332666, (1, 4): 0.19080919080919082}
# Episode 27800, Average Reward (last 100): 1439.80
# Current EDRs: {(0, 2): 0.2857142857142857, (1, 4): 0.2007992007992008}
# Episode 27900, Average Reward (last 100): 1436.80
# Current EDRs: {(0, 2): 0.34265734265734266, (1, 4): 0.14785214785214784}
# Episode 28000, Average Reward (last 100): 1439.21
# Current EDRs: {(0, 2): 0.2757242757242757, (1, 4): 0.21078921078921078}
# Episode 28100, Average Reward (last 100): 1439.93
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.1958041958041958}
# Episode 28200, Average Reward (last 100): 1438.31
# Current EDRs: {(0, 2): 0.3046953046953047, (1, 4): 0.2217782217782218}
# Episode 28300, Average Reward (last 100): 1437.14
# Current EDRs: {(0, 2): 0.3016983016983017, (1, 4): 0.18981018981018982}
# Episode 28400, Average Reward (last 100): 1431.83
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.1938061938061938}
# Episode 28500, Average Reward (last 100): 1437.12
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.1998001998001998}
# Episode 28600, Average Reward (last 100): 1444.65
# Current EDRs: {(0, 2): 0.2817182817182817, (1, 4): 0.21878121878121878}
# Episode 28700, Average Reward (last 100): 1447.18
# Current EDRs: {(0, 2): 0.2887112887112887, (1, 4): 0.23576423576423577}
# Episode 28800, Average Reward (last 100): 1442.86
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.2007992007992008}
# Episode 28900, Average Reward (last 100): 1441.39
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.2137862137862138}
# Episode 29000, Average Reward (last 100): 1439.60
# Current EDRs: {(0, 2): 0.3006993006993007, (1, 4): 0.1918081918081918}
# Episode 29100, Average Reward (last 100): 1444.75
# Current EDRs: {(0, 2): 0.28771228771228774, (1, 4): 0.22377622377622378}
# Episode 29200, Average Reward (last 100): 1439.39
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.2047952047952048}
# Episode 29300, Average Reward (last 100): 1442.67
# Current EDRs: {(0, 2): 0.28771228771228774, (1, 4): 0.2037962037962038}
# Episode 29400, Average Reward (last 100): 1446.30
# Current EDRs: {(0, 2): 0.2987012987012987, (1, 4): 0.24875124875124874}
# Episode 29500, Average Reward (last 100): 1438.83
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.2017982017982018}
# Episode 29600, Average Reward (last 100): 1443.15
# Current EDRs: {(0, 2): 0.3256743256743257, (1, 4): 0.17582417582417584}
# Episode 29700, Average Reward (last 100): 1449.65
# Current EDRs: {(0, 2): 0.2807192807192807, (1, 4): 0.20279720279720279}
# Episode 29800, Average Reward (last 100): 1445.72
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.20679320679320679}
# Episode 29900, Average Reward (last 100): 1440.64
# Current EDRs: {(0, 2): 0.3166833166833167, (1, 4): 0.18081918081918083}
# Episode 30000, Average Reward (last 100): 1441.63
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.15684315684315683}
# Episode 30100, Average Reward (last 100): 1447.21
# Current EDRs: {(0, 2): 0.31368631368631367, (1, 4): 0.17882117882117882}
# Episode 30200, Average Reward (last 100): 1450.15
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.1918081918081918}
# Episode 30300, Average Reward (last 100): 1440.18
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.16483516483516483}
# Episode 30400, Average Reward (last 100): 1449.73
# Current EDRs: {(0, 2): 0.3016983016983017, (1, 4): 0.18581418581418582}
# Episode 30500, Average Reward (last 100): 1438.36
# Current EDRs: {(0, 2): 0.32167832167832167, (1, 4): 0.18281718281718282}
# Episode 30600, Average Reward (last 100): 1440.26
# Current EDRs: {(0, 2): 0.3256743256743257, (1, 4): 0.18281718281718282}
# Episode 30700, Average Reward (last 100): 1437.46
# Current EDRs: {(0, 2): 0.28771228771228774, (1, 4): 0.1978021978021978}
# Episode 30800, Average Reward (last 100): 1438.44
# Current EDRs: {(0, 2): 0.2997002997002997, (1, 4): 0.1958041958041958}
# Episode 30900, Average Reward (last 100): 1448.76
# Current EDRs: {(0, 2): 0.2957042957042957, (1, 4): 0.1978021978021978}
# Episode 31000, Average Reward (last 100): 1444.05
# Current EDRs: {(0, 2): 0.29270729270729273, (1, 4): 0.1998001998001998}
# Episode 31100, Average Reward (last 100): 1441.44
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.1918081918081918}
# Episode 31200, Average Reward (last 100): 1438.56
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.16983016983016982}
# Episode 31300, Average Reward (last 100): 1435.48
# Current EDRs: {(0, 2): 0.3076923076923077, (1, 4): 0.1928071928071928}
# Episode 31400, Average Reward (last 100): 1436.29
# Current EDRs: {(0, 2): 0.2937062937062937, (1, 4): 0.1878121878121878}
# Episode 31500, Average Reward (last 100): 1439.62
# Current EDRs: {(0, 2): 0.2757242757242757, (1, 4): 0.1998001998001998}
# Episode 31600, Average Reward (last 100): 1439.34
# Current EDRs: {(0, 2): 0.3066933066933067, (1, 4): 0.19080919080919082}
# Episode 31700, Average Reward (last 100): 1452.55
# Current EDRs: {(0, 2): 0.2777222777222777, (1, 4): 0.1928071928071928}
# Episode 31800, Average Reward (last 100): 1439.52
# Current EDRs: {(0, 2): 0.34565434565434566, (1, 4): 0.18181818181818182}
# Episode 31900, Average Reward (last 100): 1435.91
# Current EDRs: {(0, 2): 0.27472527472527475, (1, 4): 0.21178821178821178}
# Episode 32000, Average Reward (last 100): 1444.65
# Current EDRs: {(0, 2): 0.2977022977022977, (1, 4): 0.19480519480519481}
# Episode 32100, Average Reward (last 100): 1439.96
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.16883116883116883}
# Episode 32200, Average Reward (last 100): 1443.66
# Current EDRs: {(0, 2): 0.2787212787212787, (1, 4): 0.2007992007992008}
# Episode 32300, Average Reward (last 100): 1436.01
# Current EDRs: {(0, 2): 0.3256743256743257, (1, 4): 0.1848151848151848}
# Episode 32400, Average Reward (last 100): 1444.11
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.17582417582417584}
# Episode 32500, Average Reward (last 100): 1439.13
# Current EDRs: {(0, 2): 0.32967032967032966, (1, 4): 0.18981018981018982}
# Episode 32600, Average Reward (last 100): 1447.54
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.1998001998001998}
# Episode 32700, Average Reward (last 100): 1450.86
# Current EDRs: {(0, 2): 0.34565434565434566, (1, 4): 0.18181818181818182}
# Episode 32800, Average Reward (last 100): 1441.49
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.1838161838161838}
# Episode 32900, Average Reward (last 100): 1454.30
# Current EDRs: {(0, 2): 0.2957042957042957, (1, 4): 0.21578421578421578}
# Episode 33000, Average Reward (last 100): 1448.07
# Current EDRs: {(0, 2): 0.2957042957042957, (1, 4): 0.21178821178821178}
# Episode 33100, Average Reward (last 100): 1441.01
# Current EDRs: {(0, 2): 0.2987012987012987, (1, 4): 0.1888111888111888}
# Episode 33200, Average Reward (last 100): 1446.61
# Current EDRs: {(0, 2): 0.32967032967032966, (1, 4): 0.19080919080919082}
# Episode 33300, Average Reward (last 100): 1439.50
# Current EDRs: {(0, 2): 0.3176823176823177, (1, 4): 0.2177822177822178}
# Episode 33400, Average Reward (last 100): 1440.92
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.19080919080919082}
# Episode 33500, Average Reward (last 100): 1450.91
# Current EDRs: {(0, 2): 0.2987012987012987, (1, 4): 0.1798201798201798}
# Episode 33600, Average Reward (last 100): 1452.32
# Current EDRs: {(0, 2): 0.28771228771228774, (1, 4): 0.2177822177822178}
# Episode 33700, Average Reward (last 100): 1433.11
# Current EDRs: {(0, 2): 0.3546453546453546, (1, 4): 0.16183816183816183}
# Episode 33800, Average Reward (last 100): 1442.59
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.18981018981018982}
# Episode 33900, Average Reward (last 100): 1439.53
# Current EDRs: {(0, 2): 0.33666333666333664, (1, 4): 0.17682317682317683}
# Episode 34000, Average Reward (last 100): 1437.85
# Current EDRs: {(0, 2): 0.2957042957042957, (1, 4): 0.2057942057942058}
# Episode 34100, Average Reward (last 100): 1440.42
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.2087912087912088}
# Episode 34200, Average Reward (last 100): 1447.61
# Current EDRs: {(0, 2): 0.32167832167832167, (1, 4): 0.1888111888111888}
# Episode 34300, Average Reward (last 100): 1450.93
# Current EDRs: {(0, 2): 0.33166833166833165, (1, 4): 0.19080919080919082}
# Episode 34400, Average Reward (last 100): 1445.21
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.17282717282717283}
# Episode 34500, Average Reward (last 100): 1441.79
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.18181818181818182}
# Episode 34600, Average Reward (last 100): 1448.89
# Current EDRs: {(0, 2): 0.2817182817182817, (1, 4): 0.22277722277722278}
# Episode 34700, Average Reward (last 100): 1441.16
# Current EDRs: {(0, 2): 0.3036963036963037, (1, 4): 0.18981018981018982}
# Episode 34800, Average Reward (last 100): 1437.50
# Current EDRs: {(0, 2): 0.3156843156843157, (1, 4): 0.18981018981018982}
# Episode 34900, Average Reward (last 100): 1434.70
# Current EDRs: {(0, 2): 0.28471528471528473, (1, 4): 0.21178821178821178}
# Episode 35000, Average Reward (last 100): 1435.69
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.15784215784215785}
# Episode 35100, Average Reward (last 100): 1454.16
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.15884115884115885}
# Episode 35200, Average Reward (last 100): 1437.92
# Current EDRs: {(0, 2): 0.3206793206793207, (1, 4): 0.17482517482517482}
# Episode 35300, Average Reward (last 100): 1448.22
# Current EDRs: {(0, 2): 0.29270729270729273, (1, 4): 0.2097902097902098}
# Episode 35400, Average Reward (last 100): 1445.65
# Current EDRs: {(0, 2): 0.26173826173826176, (1, 4): 0.22777222777222778}
# Episode 35500, Average Reward (last 100): 1438.42
# Current EDRs: {(0, 2): 0.2967032967032967, (1, 4): 0.20279720279720279}
# Episode 35600, Average Reward (last 100): 1440.80
# Current EDRs: {(0, 2): 0.2857142857142857, (1, 4): 0.21178821178821178}
# Episode 35700, Average Reward (last 100): 1446.41
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.18281718281718282}
# Episode 35800, Average Reward (last 100): 1445.31
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.2007992007992008}
# Episode 35900, Average Reward (last 100): 1441.53
# Current EDRs: {(0, 2): 0.3006993006993007, (1, 4): 0.19080919080919082}
# Episode 36000, Average Reward (last 100): 1448.07
# Current EDRs: {(0, 2): 0.3006993006993007, (1, 4): 0.19880119880119881}
# Episode 36100, Average Reward (last 100): 1435.35
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.1998001998001998}
# Episode 36200, Average Reward (last 100): 1440.87
# Current EDRs: {(0, 2): 0.2917082917082917, (1, 4): 0.2097902097902098}
# Episode 36300, Average Reward (last 100): 1440.57
# Current EDRs: {(0, 2): 0.32967032967032966, (1, 4): 0.1918081918081918}
# Episode 36400, Average Reward (last 100): 1448.47
# Current EDRs: {(0, 2): 0.2907092907092907, (1, 4): 0.2037962037962038}
# Episode 36500, Average Reward (last 100): 1442.21
# Current EDRs: {(0, 2): 0.3066933066933067, (1, 4): 0.18981018981018982}
# Episode 36600, Average Reward (last 100): 1450.08
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.18281718281718282}
# Episode 36700, Average Reward (last 100): 1444.28
# Current EDRs: {(0, 2): 0.2987012987012987, (1, 4): 0.1998001998001998}
# Episode 36800, Average Reward (last 100): 1448.53
# Current EDRs: {(0, 2): 0.3036963036963037, (1, 4): 0.21078921078921078}
# Episode 36900, Average Reward (last 100): 1440.60
# Current EDRs: {(0, 2): 0.3156843156843157, (1, 4): 0.1958041958041958}
# Episode 37000, Average Reward (last 100): 1444.53
# Current EDRs: {(0, 2): 0.2887112887112887, (1, 4): 0.2137862137862138}
# Episode 37100, Average Reward (last 100): 1437.48
# Current EDRs: {(0, 2): 0.3036963036963037, (1, 4): 0.2087912087912088}
# Episode 37200, Average Reward (last 100): 1445.39
# Current EDRs: {(0, 2): 0.3036963036963037, (1, 4): 0.18281718281718282}
# Episode 37300, Average Reward (last 100): 1440.63
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.18281718281718282}
# Episode 37400, Average Reward (last 100): 1445.25
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.16083916083916083}
# Episode 37500, Average Reward (last 100): 1442.97
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.17582417582417584}
# Episode 37600, Average Reward (last 100): 1446.25
# Current EDRs: {(0, 2): 0.27972027972027974, (1, 4): 0.2097902097902098}
# Episode 37700, Average Reward (last 100): 1447.16
# Current EDRs: {(0, 2): 0.3016983016983017, (1, 4): 0.1918081918081918}
# Episode 37800, Average Reward (last 100): 1440.71
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.2097902097902098}
# Episode 37900, Average Reward (last 100): 1452.13
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.17182817182817184}
# Episode 38000, Average Reward (last 100): 1450.77
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.1918081918081918}
# Episode 38100, Average Reward (last 100): 1444.29
# Current EDRs: {(0, 2): 0.2897102897102897, (1, 4): 0.1928071928071928}
# Episode 38200, Average Reward (last 100): 1449.39
# Current EDRs: {(0, 2): 0.32967032967032966, (1, 4): 0.1848151848151848}
# Episode 38300, Average Reward (last 100): 1450.26
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.18081918081918083}
# Episode 38400, Average Reward (last 100): 1440.30
# Current EDRs: {(0, 2): 0.27672327672327673, (1, 4): 0.2137862137862138}
# Episode 38500, Average Reward (last 100): 1444.67
# Current EDRs: {(0, 2): 0.3336663336663337, (1, 4): 0.16083916083916083}
# Episode 38600, Average Reward (last 100): 1449.45
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.1888111888111888}
# Episode 38700, Average Reward (last 100): 1444.53
# Current EDRs: {(0, 2): 0.3176823176823177, (1, 4): 0.17382617382617382}
# Episode 38800, Average Reward (last 100): 1439.23
# Current EDRs: {(0, 2): 0.33166833166833165, (1, 4): 0.1848151848151848}
# Episode 38900, Average Reward (last 100): 1454.70
# Current EDRs: {(0, 2): 0.2757242757242757, (1, 4): 0.20679320679320679}
# Episode 39000, Average Reward (last 100): 1438.36
# Current EDRs: {(0, 2): 0.2787212787212787, (1, 4): 0.21578421578421578}
# Episode 39100, Average Reward (last 100): 1443.51
# Current EDRs: {(0, 2): 0.3206793206793207, (1, 4): 0.1958041958041958}
# Episode 39200, Average Reward (last 100): 1445.42
# Current EDRs: {(0, 2): 0.3066933066933067, (1, 4): 0.1878121878121878}
# Episode 39300, Average Reward (last 100): 1442.83
# Current EDRs: {(0, 2): 0.2757242757242757, (1, 4): 0.21578421578421578}
# Episode 39400, Average Reward (last 100): 1443.93
# Current EDRs: {(0, 2): 0.3386613386613387, (1, 4): 0.16283716283716285}
# Episode 39500, Average Reward (last 100): 1434.73
# Current EDRs: {(0, 2): 0.3006993006993007, (1, 4): 0.18281718281718282}
# Episode 39600, Average Reward (last 100): 1448.52
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.18681318681318682}
# Episode 39700, Average Reward (last 100): 1440.26
# Current EDRs: {(0, 2): 0.2997002997002997, (1, 4): 0.19080919080919082}
# Episode 39800, Average Reward (last 100): 1455.53
# Current EDRs: {(0, 2): 0.2897102897102897, (1, 4): 0.1878121878121878}
# Episode 39900, Average Reward (last 100): 1445.26
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.15784215784215785}
# Episode 40000, Average Reward (last 100): 1443.56
# Current EDRs: {(0, 2): 0.3066933066933067, (1, 4): 0.17682317682317683}
# Episode 40100, Average Reward (last 100): 1445.39
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.2077922077922078}
# Episode 40200, Average Reward (last 100): 1441.97
# Current EDRs: {(0, 2): 0.2867132867132867, (1, 4): 0.1998001998001998}
# Episode 40300, Average Reward (last 100): 1437.73
# Current EDRs: {(0, 2): 0.33466533466533466, (1, 4): 0.16083916083916083}
# Episode 40400, Average Reward (last 100): 1436.81
# Current EDRs: {(0, 2): 0.34265734265734266, (1, 4): 0.17082917082917082}
# Episode 40500, Average Reward (last 100): 1435.47
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.19080919080919082}
# Episode 40600, Average Reward (last 100): 1446.99
# Current EDRs: {(0, 2): 0.27472527472527475, (1, 4): 0.20679320679320679}
# Episode 40700, Average Reward (last 100): 1435.22
# Current EDRs: {(0, 2): 0.3096903096903097, (1, 4): 0.2047952047952048}
# Episode 40800, Average Reward (last 100): 1440.41
# Current EDRs: {(0, 2): 0.27372627372627373, (1, 4): 0.22877122877122877}
# Episode 40900, Average Reward (last 100): 1445.51
# Current EDRs: {(0, 2): 0.3256743256743257, (1, 4): 0.17782217782217782}
# Episode 41000, Average Reward (last 100): 1443.64
# Current EDRs: {(0, 2): 0.2957042957042957, (1, 4): 0.1968031968031968}
# Episode 41100, Average Reward (last 100): 1445.89
# Current EDRs: {(0, 2): 0.2937062937062937, (1, 4): 0.2087912087912088}
# Episode 41200, Average Reward (last 100): 1443.21
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.2017982017982018}
# Episode 41300, Average Reward (last 100): 1444.72
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.19480519480519481}
# Episode 41400, Average Reward (last 100): 1439.28
# Current EDRs: {(0, 2): 0.33666333666333664, (1, 4): 0.1938061938061938}
# Episode 41500, Average Reward (last 100): 1445.24
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.1938061938061938}
# Episode 41600, Average Reward (last 100): 1439.23
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.1928071928071928}
# Episode 41700, Average Reward (last 100): 1435.73
# Current EDRs: {(0, 2): 0.3076923076923077, (1, 4): 0.1978021978021978}
# Episode 41800, Average Reward (last 100): 1451.72
# Current EDRs: {(0, 2): 0.33766233766233766, (1, 4): 0.18981018981018982}
# Episode 41900, Average Reward (last 100): 1433.51
# Current EDRs: {(0, 2): 0.33466533466533466, (1, 4): 0.15684315684315683}
# Episode 42000, Average Reward (last 100): 1442.59
# Current EDRs: {(0, 2): 0.32167832167832167, (1, 4): 0.14985014985014986}
# Episode 42100, Average Reward (last 100): 1441.63
# Current EDRs: {(0, 2): 0.32667332667332666, (1, 4): 0.17782217782217782}
# Episode 42200, Average Reward (last 100): 1437.84
# Current EDRs: {(0, 2): 0.2987012987012987, (1, 4): 0.22077922077922077}
# Episode 42300, Average Reward (last 100): 1447.68
# Current EDRs: {(0, 2): 0.32367632367632365, (1, 4): 0.1838161838161838}
# Episode 42400, Average Reward (last 100): 1449.75
# Current EDRs: {(0, 2): 0.32667332667332666, (1, 4): 0.17882117882117882}
# Episode 42500, Average Reward (last 100): 1436.04
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.17882117882117882}
# Episode 42600, Average Reward (last 100): 1448.79
# Current EDRs: {(0, 2): 0.3096903096903097, (1, 4): 0.2087912087912088}
# Episode 42700, Average Reward (last 100): 1445.79
# Current EDRs: {(0, 2): 0.33766233766233766, (1, 4): 0.18081918081918083}
# Episode 42800, Average Reward (last 100): 1445.31
# Current EDRs: {(0, 2): 0.32367632367632365, (1, 4): 0.18181818181818182}
# Episode 42900, Average Reward (last 100): 1449.10
# Current EDRs: {(0, 2): 0.2897102897102897, (1, 4): 0.2177822177822178}
# Episode 43000, Average Reward (last 100): 1443.20
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.17482517482517482}
# Episode 43100, Average Reward (last 100): 1439.70
# Current EDRs: {(0, 2): 0.28471528471528473, (1, 4): 0.18981018981018982}
# Episode 43200, Average Reward (last 100): 1443.38
# Current EDRs: {(0, 2): 0.3356643356643357, (1, 4): 0.16283716283716285}
# Episode 43300, Average Reward (last 100): 1444.73
# Current EDRs: {(0, 2): 0.27672327672327673, (1, 4): 0.21478521478521478}
# Episode 43400, Average Reward (last 100): 1448.92
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.17482517482517482}
# Episode 43500, Average Reward (last 100): 1451.39
# Current EDRs: {(0, 2): 0.28771228771228774, (1, 4): 0.1998001998001998}
# Episode 43600, Average Reward (last 100): 1440.39
# Current EDRs: {(0, 2): 0.3246753246753247, (1, 4): 0.16483516483516483}
# Episode 43700, Average Reward (last 100): 1437.91
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.21878121878121878}
# Episode 43800, Average Reward (last 100): 1437.55
# Current EDRs: {(0, 2): 0.33266733266733267, (1, 4): 0.17782217782217782}
# Episode 43900, Average Reward (last 100): 1437.60
# Current EDRs: {(0, 2): 0.3436563436563437, (1, 4): 0.1798201798201798}
# Episode 44000, Average Reward (last 100): 1438.04
# Current EDRs: {(0, 2): 0.32367632367632365, (1, 4): 0.20279720279720279}
# Episode 44100, Average Reward (last 100): 1445.96
# Current EDRs: {(0, 2): 0.35664335664335667, (1, 4): 0.17582417582417584}
# Episode 44200, Average Reward (last 100): 1441.09
# Current EDRs: {(0, 2): 0.25674325674325676, (1, 4): 0.22477522477522477}
# Episode 44300, Average Reward (last 100): 1443.71
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.18081918081918083}
# Episode 44400, Average Reward (last 100): 1444.19
# Current EDRs: {(0, 2): 0.3336663336663337, (1, 4): 0.17682317682317683}
# Episode 44500, Average Reward (last 100): 1439.97
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.1978021978021978}
# Episode 44600, Average Reward (last 100): 1436.62
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.2017982017982018}
# Episode 44700, Average Reward (last 100): 1446.34
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.21078921078921078}
# Episode 44800, Average Reward (last 100): 1446.67
# Current EDRs: {(0, 2): 0.2997002997002997, (1, 4): 0.2047952047952048}
# Episode 44900, Average Reward (last 100): 1446.22
# Current EDRs: {(0, 2): 0.33266733266733267, (1, 4): 0.18981018981018982}
# Episode 45000, Average Reward (last 100): 1441.91
# Current EDRs: {(0, 2): 0.3106893106893107, (1, 4): 0.17382617382617382}
# Episode 45100, Average Reward (last 100): 1442.78
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.18681318681318682}
# Episode 45200, Average Reward (last 100): 1442.30
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.17882117882117882}
# Episode 45300, Average Reward (last 100): 1438.77
# Current EDRs: {(0, 2): 0.3046953046953047, (1, 4): 0.19080919080919082}
# Episode 45400, Average Reward (last 100): 1445.86
# Current EDRs: {(0, 2): 0.32167832167832167, (1, 4): 0.1878121878121878}
# Episode 45500, Average Reward (last 100): 1438.16
# Current EDRs: {(0, 2): 0.3756243756243756, (1, 4): 0.1798201798201798}
# Episode 45600, Average Reward (last 100): 1445.97
# Current EDRs: {(0, 2): 0.32167832167832167, (1, 4): 0.18281718281718282}
# Episode 45700, Average Reward (last 100): 1443.48
# Current EDRs: {(0, 2): 0.3026973026973027, (1, 4): 0.1968031968031968}
# Episode 45800, Average Reward (last 100): 1447.15
# Current EDRs: {(0, 2): 0.34465534465534464, (1, 4): 0.18281718281718282}
# Episode 45900, Average Reward (last 100): 1448.71
# Current EDRs: {(0, 2): 0.37462537462537465, (1, 4): 0.15484515484515485}
# Episode 46000, Average Reward (last 100): 1449.40
# Current EDRs: {(0, 2): 0.32867132867132864, (1, 4): 0.16483516483516483}
# Episode 46100, Average Reward (last 100): 1443.85
# Current EDRs: {(0, 2): 0.3196803196803197, (1, 4): 0.18281718281718282}
# Episode 46200, Average Reward (last 100): 1448.28
# Current EDRs: {(0, 2): 0.3156843156843157, (1, 4): 0.18581418581418582}
# Episode 46300, Average Reward (last 100): 1446.35
# Current EDRs: {(0, 2): 0.3156843156843157, (1, 4): 0.17782217782217782}
# Episode 46400, Average Reward (last 100): 1447.43
# Current EDRs: {(0, 2): 0.3116883116883117, (1, 4): 0.1928071928071928}
# Episode 46500, Average Reward (last 100): 1451.13
# Current EDRs: {(0, 2): 0.3206793206793207, (1, 4): 0.18181818181818182}
# Episode 46600, Average Reward (last 100): 1452.19
# Current EDRs: {(0, 2): 0.33266733266733267, (1, 4): 0.18281718281718282}
# Episode 46700, Average Reward (last 100): 1448.84
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.16083916083916083}
# Episode 46800, Average Reward (last 100): 1448.90
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.1928071928071928}
# Episode 46900, Average Reward (last 100): 1441.56
# Current EDRs: {(0, 2): 0.2897102897102897, (1, 4): 0.20679320679320679}
# Episode 47000, Average Reward (last 100): 1437.62
# Current EDRs: {(0, 2): 0.3126873126873127, (1, 4): 0.2127872127872128}
# Episode 47100, Average Reward (last 100): 1438.99
# Current EDRs: {(0, 2): 0.31368631368631367, (1, 4): 0.17382617382617382}
# Episode 47200, Average Reward (last 100): 1444.99
# Current EDRs: {(0, 2): 0.3016983016983017, (1, 4): 0.20279720279720279}
# Episode 47300, Average Reward (last 100): 1444.58
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.1928071928071928}
# Episode 47400, Average Reward (last 100): 1449.37
# Current EDRs: {(0, 2): 0.3336663336663337, (1, 4): 0.1958041958041958}
# Episode 47500, Average Reward (last 100): 1449.02
# Current EDRs: {(0, 2): 0.3096903096903097, (1, 4): 0.17682317682317683}
# Episode 47600, Average Reward (last 100): 1447.26
# Current EDRs: {(0, 2): 0.3256743256743257, (1, 4): 0.1958041958041958}
# Episode 47700, Average Reward (last 100): 1438.17
# Current EDRs: {(0, 2): 0.3096903096903097, (1, 4): 0.18681318681318682}
# Episode 47800, Average Reward (last 100): 1442.00
# Current EDRs: {(0, 2): 0.3226773226773227, (1, 4): 0.17482517482517482}
# Episode 47900, Average Reward (last 100): 1441.32
# Current EDRs: {(0, 2): 0.28771228771228774, (1, 4): 0.1968031968031968}
# Episode 48000, Average Reward (last 100): 1441.18
# Current EDRs: {(0, 2): 0.3206793206793207, (1, 4): 0.1888111888111888}
# Episode 48100, Average Reward (last 100): 1441.48
# Current EDRs: {(0, 2): 0.31868131868131866, (1, 4): 0.19880119880119881}
# Episode 48200, Average Reward (last 100): 1441.17
# Current EDRs: {(0, 2): 0.3006993006993007, (1, 4): 0.21178821178821178}
# Episode 48300, Average Reward (last 100): 1449.41
# Current EDRs: {(0, 2): 0.32967032967032966, (1, 4): 0.17682317682317683}
# Episode 48400, Average Reward (last 100): 1445.87
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.17682317682317683}
# Episode 48500, Average Reward (last 100): 1439.88
# Current EDRs: {(0, 2): 0.34065934065934067, (1, 4): 0.16483516483516483}
# Episode 48600, Average Reward (last 100): 1443.64
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.1978021978021978}
# Episode 48700, Average Reward (last 100): 1442.27
# Current EDRs: {(0, 2): 0.3246753246753247, (1, 4): 0.17682317682317683}
# Episode 48800, Average Reward (last 100): 1446.61
# Current EDRs: {(0, 2): 0.32167832167832167, (1, 4): 0.1918081918081918}
# Episode 48900, Average Reward (last 100): 1442.44
# Current EDRs: {(0, 2): 0.3166833166833167, (1, 4): 0.1928071928071928}
# Episode 49000, Average Reward (last 100): 1438.88
# Current EDRs: {(0, 2): 0.3086913086913087, (1, 4): 0.18681318681318682}
# Episode 49100, Average Reward (last 100): 1437.84
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.19480519480519481}
# Episode 49200, Average Reward (last 100): 1435.35
# Current EDRs: {(0, 2): 0.2947052947052947, (1, 4): 0.18181818181818182}
# Episode 49300, Average Reward (last 100): 1443.66
# Current EDRs: {(0, 2): 0.3076923076923077, (1, 4): 0.17782217782217782}
# Episode 49400, Average Reward (last 100): 1445.74
# Current EDRs: {(0, 2): 0.2917082917082917, (1, 4): 0.1848151848151848}
# Episode 49500, Average Reward (last 100): 1440.52
# Current EDRs: {(0, 2): 0.28471528471528473, (1, 4): 0.2087912087912088}
# Episode 49600, Average Reward (last 100): 1445.01
# Current EDRs: {(0, 2): 0.34165834165834164, (1, 4): 0.17082917082917082}
# Episode 49700, Average Reward (last 100): 1446.24
# Current EDRs: {(0, 2): 0.3146853146853147, (1, 4): 0.17582417582417584}
# Episode 49800, Average Reward (last 100): 1438.27
# Current EDRs: {(0, 2): 0.3076923076923077, (1, 4): 0.20679320679320679}
# Episode 49900, Average Reward (last 100): 1441.37
# Current EDRs: {(0, 2): 0.30569430569430567, (1, 4): 0.17682317682317683}
# Episode 50000, Average Reward (last 100): 1451.01
# Current EDRs: {(0, 2): 0.33166833166833165, (1, 4): 0.20279720279720279}
# === Convergence Statistics ===
#
# Last 100 episodes:
# Average reward: 1451.01
# Reward std dev: 38.73
# Average Q-value: 147.89
#
# Final EDRs:
# Goal (0, 2): 0.3169
# Goal (1, 4): 0.1852
#
# Last 500 episodes:
# Average reward: 1444.38
# Reward std dev: 45.73
# Average Q-value: 147.96
#
# Final EDRs:
# Goal (0, 2): 0.3181
# Goal (1, 4): 0.1851
#
# Last 1000 episodes:
# Average reward: 1442.50
# Reward std dev: 45.37
# Average Q-value: 148.16
#
# Final EDRs:
# Goal (0, 2): 0.3179
# Goal (1, 4): 0.1851
#
# === Final Statistics ===
# Parameters: pSwap=0.8, pGen=0.8, maxAge=2
# Network: edges=[(0, 1), (1, 2), (2, 3), (3, 4)], goals=[(0, 2), (1, 4)]
#
# Final EDRs (Last Episode):
# Goal (0, 2): EDR = 0.332000
#   - Successes: 332
#   - Total timesteps: 1000
# Goal (1, 4): EDR = 0.203000
#   - Successes: 203
#   - Total timesteps: 1000
#
# Final Average Reward (last 100 episodes): 1451.0131
